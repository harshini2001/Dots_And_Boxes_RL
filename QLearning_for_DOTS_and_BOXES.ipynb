# %%
# !pip install bitstring
# Out:
# Collecting bitstring
#   Downloading https://files.pythonhosted.org/packages/c3/fc/ffac2c199d2efe1ec5111f55efeb78f5f2972456df6939fea849f103f9f5/bitstring-3.1.7.tar.gz (195kB)
#      |████████████████████████████████| 204kB 7.5MB/s
# Building wheels for collected packages: bitstring
#   Building wheel for bitstring (setup.py) ... done
#   Created wheel for bitstring: filename=bitstring-3.1.7-cp37-none-any.whl size=37949 sha256=ea4fc5d47e77d0fd1e07df3ff7516e0dde237c3800ead2071d1172a400d354a8
#   Stored in directory: /root/.cache/pip/wheels/b8/27/f0/8373e26b7de57db03dc18aaaebdd8c26a99da882416f762979
# Successfully built bitstring
# Installing collected packages: bitstring
# Successfully installed bitstring-3.1.7

# %% [markdown]
# ## ML ASSIGNMENT BATCH 8
# - Deepthishree GS
# - Harshini S
# - Iswarya GP
# - Janani R
# - Swetha M
#
# ### ***TOPIC*** - REINFORCEMENT LEARNING
# ### ***Problem Taken*** : Playing Dots and Boxes using a Q learning Agent
#
# ![image](https://user-images.githubusercontent.com/43994542/112790879-f9220480-907d-11eb-8dae-c041684a9523.png)

# %% [markdown]
# ## Importing Libraries

# %%
from bitstring import BitArray
# This library is used to store and convert the board state. 
# Board state is stored as bitarray with one indicating a line and zero indicating no line
import numpy as np
import random
# To make random moves in initial exploration phase
import json
# Save the QTABLE finally as a json file to continue training incrementally when the kernal restarts

# %% [markdown]
# ## Global Variables declaration

# %%
'''
3x3 dots and boxes 
4 boxes can be drawn
12 lines to choose from for each move
2 power 12 game states for the agent to learn from
DRAW / TIE is available in this version of the game (in original version in case of tie, person who starts loses)
Reward 100 and Penalty -100 (for each box drawn)
Reward 200 and Penalty -200 (long term finally at the end)
Reward 50 for a tie game at end
'''
QTable=dict()
# This table is the ultimate QTable to be learnt by our agent
'''
Q TABLE usually has states as rows and actions as columns and the entries are the corresponding Q values

Since in a game, only legal moves are the actions, the number of columns(moves) for each state is different

So, a hash table is constructed with keys as states and values as action:qvalue pairs
'''
VISIT_TABLE=dict()
# This table has the count of visits for each state. This ensures that we can check if all states are visited often (An assumption for Q Learning Convergence in TOM MITCHELL book)
DISCOUNT_RATE=0.8
# This decreases the future rewards by a factor each step
LEARNING_RATE=0.2
# This makes sure table is learnt at a specified. A balance between existing value and updated value
# Small LRate values ensure the table is not drastically updated

# %% [markdown]
# ### Main Function for LEARNER
# - Algorithm is play games repeatedly and update the Q Table
# - Calls subfunction playGame
#
# #### Main Functions:
# - Decide the choice of move for agent as random, simple or qlearner
# - Ensures where the learner is exploring or exploiting
# - Random and simple for exploration
#   - Random makes random moves
#   - Simple makes the move with least visit count for the next state (Thus makes sure the same state is not repeated often and unvisited states are explored)
# - Qlearner exploits
#   - This makes the move where the Q value for the next state is maximum

# %%
def learner(gameCount=1000): #default no of games if the trainer doesn't specify the games

    count=1
    # counter to keep track of number of games
    # choiceOfMove=['random','simple','qlearner']
    # choice for deciding exploration or exploitation
    while count<gameCount:
        print("GAME ",count)
        #print the game number to know the progress of learner
        if count<gameCount/10:
            playGame(choiceOfMove='random',firstMove=1,withHuman=False) 
        #First 10% games are random
        elif count<gameCount/2:
            playGame(choiceOfMove='simple',firstMove=1,withHuman=False)
        #Till 50% the games are moved by a simple agent - Exploring the unvisited states
        else:
            playGame(choiceOfMove='qlearner',firstMove=1,withHuman=False)
        #Last 50% of games is exploited by QLearner
        count+=1
        with open('Qtable.json','w') as jsonfile:
          json.dump(QTable,jsonfile)
        # Each game, the current QTABLE is backed up incase the kernel restarts and values are lost

# %% [markdown]
# ### Initialises the Main Q Table
# - Q TABLE usually has states as rows and actions as columns and the entries are the corresponding Q values
#
# - Since in a game, only legal moves are the actions, the number of columns(moves) for each state is different
#
# - So, a hash table is constructed with keys as states and values as action:qvalue pairs
#
# - All values are init to 0 now

# %%
def initialiseQTable():
    global QTable
    global VISIT_TABLE
    # The global variables are initialised in this function
    for i in range(4096):
      '''
      The number of states is 2 power 12 which is 4096
      QTABLE rows (in our case the keys of the hashtable are 4096 in number )

      For each state, each line which can be drawn is a possible action. 
      Initial state = 000000000000 => has 12 possible actions
      Some state    = 000011110000 => has 8 zeros and 4 ones. 
                      Out of the 12 lines, 4 are drawn. 8 lines are free to be drawn for next move.
                      The possible line numbers which can be drawn are the possible actions
                      EACH ZERO is a possible action. Here, 1,2,3,4 and 9,10,11,12 are the 8 possible actions. 
      So, the actions are initialised as another dictionary and 0 is the current initialisation for Q value
      '''
      currentState=BitArray(uint=i, length=12)
      actionQvalues=dict()
      # find possible actions
      bitString=currentState.bin
      # convert bitarray to bitstring to store as key
      for index in range(len(bitString)):
          if bitString[index]=='0':
              actionQvalues[index+1]=0
            
          #EACH ZERO in this state is a possible action when making next move from this state
          # index + 1 because line number index starts from 1 for ease of human player

      QTable[currentState.bin]=actionQvalues
      VISIT_TABLE[currentState.bin]=0
      # EACH State visit count is init to 0 
      QTable['111111111111']={0:0}
      # FINAL BOARD STATE HAS ONLY ONE POSSIBLE ACTION - NO MOVE - 0 is set as action which is not a valid line number (line numbers start from 1 to 12)

# %% [markdown]
# ### Best action given a state
# Function used by QLearner to select the action or move which has maximum QValue for all possible actioins in the given state

# %%
#This is the function to choice best action for the  given state using Qvalue in QTable
def bestActionForState(state):
    maxQval=-2000 #negative inf
    bestAction=0
    for action,qval in QTable[state].items():
        # QTABLE has all valid actions for current state and their QValues
        if qval>maxQval:
            maxQval=qval # Find the maximum qvalue
            bestAction=action # Find the corresponding best action
    return bestAction

# %% [markdown]
# ### UPDATE QTABLE
# - This function uses the formula for QLearning and updates the moves in reverse chronological order
# - This is called after each game is over
# - This finetuning is what makes the agent learn the game
# - According to Tom Mitchell book, update for QTable values is as
#   `Q(s,a) = (1-LR)*Q(s,a)+LR*(rwd+DR*MAX(Q(ns,all a's)))`
#   - First term is existing term
#   - Second term is update term
#   - LR and DR are learning and discount rate respectively

# %%
def updateQTable(memoryOfPlayerMoves):
    global QTable
    memoryOfPlayerMoves=memoryOfPlayerMoves[::-1] #reverse chronological order
    '''
    The first few moves have no rewards. According to Tom Mitchell book, the sequence of updates have no impact. 
    Therefore, it is efficient to propagate the effect of rewards from current move to the previous moves. 
    This helps us indirectly since we have rewards only for end result and certain important points in game.
    For remaining moves the immediate reward is 0
    '''
    for state,action,nextState,reward in memoryOfPlayerMoves:
        maxQValForNextState=QTable[nextState][bestActionForState(nextState)]
        # Finding the maximum QValue for next state to update future rewards along with a discount
        existingValue=(1-LEARNING_RATE)*QTable[state][action]
        # Existing value is taken by a fraction as indicated by learning rate to prevent drastic updates in Qtable
        updateValue=LEARNING_RATE*(reward+DISCOUNT_RATE*maxQValForNextState)
        # UPDATE value is immediate reward + Discount rate * future rewards
        # ACCORDING TO an equation in Tom Mitchell book
        QTable[state][action]=existingValue+updateValue
        VISIT_TABLE[state]+=1
        #Since this state is visited, its visit count is incremented

# %% [markdown]
# ### Print board state
# - Print the board state so that the human can understand what are the boxes formed and what could be the potential next move during a game

# %%
#Printing 3*3 table
def printBoardState(currentState):
    count=1
    m=7
    # 6 horizontal lines and from 7 vertical lines. m=7 means from m it will print accordingly
    for i in range(3):
        for j in range(3):
            print(".\t", end=" ")
            if j<2:
                if currentState[count-1]=='0':
                    print(str(count)+"\t",end=" ") 
                else:
                    print("--\t",end=" ")
                count+=1
        #printing horizontal line
                
        print("\n")
        if i!=2:
            for k in range(3):
                if currentState[m-1]=='0':
                    print(str(m)+"\t\t",end=" ")
                else:
                    print("|\t\t",end=" ")
                m+=1
        #printing vertical lines
        print("\n")
printBoardState(12*'0') # 12 zeros are initial board state
# Out:
# .	 1	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .

# %% [markdown]
# ### MakeMove or ChooseAction
# - First few games, learner uses random moves
# - Next it uses an approach to select states with very less visit count.
# - These are for exploration
# - After that, the game is carried forward by the QLearner
#
# - Human can choose any of the three for choice of making move for his/her opponent

# %%
'''
  Three choices are considered for a move (ie) Random, simple and qlearner
  Random move will choose random move from the actions that are available for a particular board state.
  Simple move will choose the action for the state with minimum count.
  Qlearner will choose best action for a state using Qvalues in the QTable
  Random and Simple move are used for explore new states and actions.
  QLearner is for exploitation.
'''
def MakeMove(currentState,choice):
    # possible actions
    possibleActions=list(QTable[currentState].keys())
    #choiceOfMove=['random','simple','qlearner']
    if choice=='random':
        #returning random action from the possible actions.
        return possibleActions[random.randint(0,len(possibleActions)-1)]
        
    if choice=='simple':
        minCount=1000000
        action=0
        for action in possibleActions:
            #VISIT_TABLE stores how many times the states have been visited for each action.
            #Return least visited state ie. explore unvisited states
            if VISIT_TABLE[transition(currentState,action)]<minCount:
                minCount=VISIT_TABLE[transition(currentState,action)]
                bestAction=action     
        return bestAction
    if choice=='qlearner':
        # return the best action that maximises QVALUE. Helper function name is bestActionForState
        return bestActionForState(currentState)

# %% [markdown]
# ### Checks if the game is over

# %%
'''
End state for a board is '111111111111' -> all lines are drawn. 12 lines are drawn in final state. 
This function compares current state with end state and checks if currrent state is End state
'''
def isBoardStateFinal(boardState):
    return boardState.bin==12*'1'

# %% [markdown]
# ### Transition function
# - Takes input as current state and move and gives the next state as output

# %%
'''
It outputs the next state.
Ex: currentState is '100000000000' and current move is line number 12, then
it will return '100000000001' as the nextstate
'''
def transition(currentState,currentMove):
    temp=currentState
    temp=temp[:currentMove-1]+'1'+temp[currentMove:]
    #It copies through string splicing every line till current move and every line after current move and adds 1 in current move's place
    return temp

# %% [markdown]
# ### Counts the number of boxes formed during the move to update points

# %%
'''
This function will check whether the box is formed or not. If so, it will return the
number of boxes formed for that move. If not, it will return 0 .
  .    1   .    2     . 
  
  7        8          9

  .    3   .     4    .

  10       11         12

  .    5    .   6      .

  Line numbers 1,3,7,8 will form one box and 2,4,8,9 will form another box
  and 3,5,10,11 will form third box and 4,6,11,12 will form the last box
'''
def numberOfNewBoxFormed(box,newState):
    count=0
    boxBounds=[[1,3,7,8],[2,4,8,9],[3,5,10,11],[4,6,11,12]]
    #box is the state of boxes already filled in the game
    # we check if a new box is formed and update it. (list is passed by reference. No need to return)
    for i in range(len(boxBounds)):
      if box[i]==0:
        #This box is not filled till last state
        flag=True
        #Flag indicates possibility of filling the box
        for lineNumber in boxBounds[i]:
          #Even if one line is not drawn out of the 4, flag is marked false
          if newState[lineNumber-1]!='1':
            flag=False
            break
        # IF a new box is drawn, we increment the count by one
        if flag==True:
          count+=1
          box[i]=1
    # WE return count of new boxes formed by drawing a single line . Note that it can be greater than 1 also
    return count
    # This count will be used to update the player score and give reward and penalty accordingly

# %% [markdown]
# ### Main function where the game is played
#
# Algo
# - init board state
# - init players as p1, p2 or p1, human
# - init current player = p1
# - init box [0 0 0 0]
# - while not final state:
#     - if cp != 'human' :
#         currentplayer.make move // simple, q learner , random .. 3 boxes..
#     - else:
#         accept input
#     - update currentplayer.memory
#     - Check if new box formed, update player score
#     - else
#     -   toggle the currentplayer
#     - update board state with current move
# - update QTABLE with rewards and penalties

# %%
'''
Similar to algorithm shown in markdown

'''

def playGame(choiceOfMove,firstMove,withHuman=False): #choice of Move is the type of agent (random or simple or QLearner )
#firstMove = 1 if agent makes first move else human can make first move
#argument withHuman is set TRUE to accept move from user

    #Game init
    player=["p1","p2"]
    #players p1, p2
    if withHuman:
        player[1]='human'
    # decide if p2 or human
    if firstMove==2:
      currentPlayer='human'
    else:
      currentPlayer='p1'
    # who makes the first move
    box=[0,0,0,0]
    # Which are boxes completed. It is updated to keep score
    currentState=BitArray(uint=0, length=12)
    # INITIAL board state
    memory={player[0]:[],player[1]:[]}
    score={player[0]:0,player[1]:0}
    # INITIALISE memory of a game and score
    while isBoardStateFinal(currentState)==False: # while the game is not over
        if(currentPlayer!="human"):
            currentMove=MakeMove(currentState.bin,choiceOfMove) # call makeMove function and the agent will return move
        else:
          possibleActions=list(QTable[currentState.bin].keys())
          currentMove=int(input("Enter the line number:"))
          while currentMove not in possibleActions:
            currentMove=int(input("INVALID! Enter the line number:"))
          #accept user input and check if it is valid

        newState=transition(currentState.bin,currentMove) 
        # Transition is made with the move
        memory[currentPlayer].append([currentState.bin,currentMove,newState,0])
        # Memory of the current move is added to player game memory
        numberOfBoxes=numberOfNewBoxFormed(box,newState)
        # Checks if new box is formed, if so score is updated
        if numberOfBoxes>0:#Short term rewards are given for boxes and score is updated
            score[currentPlayer]+=numberOfBoxes*2
            memory[currentPlayer][-1][-1]=100
            memory[player[1-player.index(currentPlayer)]][-1][-1]=-100

        else: #toggle the current player to give the turn to next player
            currentPlayer=player[1-player.index(currentPlayer)]

        currentState=BitArray(uint=int(newState,2),length=12)
        #update current state based on the transition obtained

        if player[1]=='human':            
            printBoardState(currentState.bin)
            print("Score of ",player[0]," is ",score[player[0]])
            print("Score of ",player[1]," is ",score[player[1]])
            if isBoardStateFinal(currentState)==False:
              print("Next turn for ",currentPlayer)
            #print each move if human is playing 

    #game over now
    #find winner 
    result=""
    if score[player[0]]==score[player[1]]: # find if scores are same
        result='TIE'
        print(result)
    else:
        result=max(score,key=score.get) # find the winner
        print("Winner is ",result)
    #print(memory[player[0]])
    # reward is given for tie, winner, penalty for loser
    if result=='TIE':
        memory[player[0]][-1][-1]=50
        memory[player[1]][-1][-1]=50
    else: 
        memory[result][-1][-1]=200
        memory[player[1-player.index(result)]][-1][-1]=-200
    # print(memory[player[0]])
    # print(memory[player[1]])    
    #put reward and penalties in last row of the memory table
    updateQTable(memory[player[0]])
    updateQTable(memory[player[1]])
    # update the QTABLE 
    return result

# %% [markdown]
# ### Learn and test performance
# - Step 1 : INITIALISE QTABLE
# - Step 2 : Learn by playing games
# - Step 3 : Play against human ( can specify who makes first move)

# %%
initialiseQTable()
# set 0 to all QValues 
learner(gameCount=10000)
# specify the number of games learning agent has to played
# Out:
# Streaming output truncated to the last 5000 lines.
# GAME  7500
# Winner is  p1
# GAME  7501
# Winner is  p1
# GAME  7502
# Winner is  p1
# GAME  7503
# Winner is  p1
# GAME  7504
# Winner is  p1
# GAME  7505
# Winner is  p1
# GAME  7506
# Winner is  p1
# GAME  7507
# Winner is  p1
# GAME  7508
# Winner is  p1
# GAME  7509
# Winner is  p1
# GAME  7510
# Winner is  p1
# GAME  7511
# Winner is  p1
# GAME  7512
# Winner is  p1
# GAME  7513
# Winner is  p1
# GAME  7514
# Winner is  p1
# GAME  7515
# Winner is  p1
# GAME  7516
# Winner is  p1
# GAME  7517
# Winner is  p1
# GAME  7518
# Winner is  p1
# GAME  7519
# Winner is  p1
# GAME  7520
# Winner is  p1
# GAME  7521
# Winner is  p1
# GAME  7522
# Winner is  p1
# GAME  7523
# Winner is  p1
# GAME  7524
# Winner is  p1
# GAME  7525
# Winner is  p1
# GAME  7526
# Winner is  p1
# GAME  7527
# Winner is  p1
# GAME  7528
# Winner is  p1
# GAME  7529
# Winner is  p1
# GAME  7530
# Winner is  p1
# GAME  7531
# Winner is  p1
# GAME  7532
# Winner is  p1
# GAME  7533
# Winner is  p1
# GAME  7534
# Winner is  p1
# GAME  7535
# Winner is  p1
# GAME  7536
# Winner is  p1
# GAME  7537
# Winner is  p1
# GAME  7538
# Winner is  p1
# GAME  7539
# Winner is  p1
# GAME  7540
# Winner is  p1
# GAME  7541
# Winner is  p1
# GAME  7542
# Winner is  p1
# GAME  7543
# Winner is  p1
# GAME  7544
# Winner is  p1
# GAME  7545
# Winner is  p1
# GAME  7546
# Winner is  p1
# GAME  7547
# Winner is  p1
# GAME  7548
# Winner is  p1
# GAME  7549
# Winner is  p1
# GAME  7550
# Winner is  p1
# GAME  7551
# Winner is  p1
# GAME  7552
# Winner is  p1
# GAME  7553
# Winner is  p1
# GAME  7554
# Winner is  p1
# GAME  7555
# Winner is  p1
# GAME  7556
# Winner is  p1
# GAME  7557
# Winner is  p1
# GAME  7558
# Winner is  p1
# GAME  7559
# Winner is  p1
# GAME  7560
# Winner is  p1
# GAME  7561
# Winner is  p1
# GAME  7562
# Winner is  p1
# GAME  7563
# Winner is  p1
# GAME  7564
# Winner is  p1
# GAME  7565
# Winner is  p1
# GAME  7566
# Winner is  p1
# GAME  7567
# Winner is  p1
# GAME  7568
# Winner is  p1
# GAME  7569
# Winner is  p1
# GAME  7570
# Winner is  p1
# GAME  7571
# Winner is  p1
# GAME  7572
# Winner is  p1
# GAME  7573
# Winner is  p1
# GAME  7574
# Winner is  p1
# GAME  7575
# Winner is  p1
# GAME  7576
# Winner is  p1
# GAME  7577
# Winner is  p1
# GAME  7578
# Winner is  p1
# GAME  7579
# Winner is  p1
# GAME  7580
# Winner is  p1
# GAME  7581
# Winner is  p1
# GAME  7582
# Winner is  p1
# GAME  7583
# Winner is  p1
# GAME  7584
# Winner is  p1
# GAME  7585
# Winner is  p1
# GAME  7586
# Winner is  p1
# GAME  7587
# Winner is  p1
# GAME  7588
# Winner is  p1
# GAME  7589
# Winner is  p1
# GAME  7590
# Winner is  p1
# GAME  7591
# Winner is  p1
# GAME  7592
# Winner is  p1
# GAME  7593
# Winner is  p1
# GAME  7594
# Winner is  p1
# GAME  7595
# Winner is  p1
# GAME  7596
# Winner is  p1
# GAME  7597
# Winner is  p1
# GAME  7598
# Winner is  p1
# GAME  7599
# Winner is  p1
# GAME  7600
# Winner is  p1
# GAME  7601
# Winner is  p1
# GAME  7602
# Winner is  p1
# GAME  7603
# Winner is  p1
# GAME  7604
# Winner is  p1
# GAME  7605
# Winner is  p1
# GAME  7606
# Winner is  p1
# GAME  7607
# Winner is  p1
# GAME  7608
# Winner is  p1
# GAME  7609
# Winner is  p1
# GAME  7610
# Winner is  p1
# GAME  7611
# Winner is  p1
# GAME  7612
# Winner is  p1
# GAME  7613
# Winner is  p1
# GAME  7614
# Winner is  p1
# GAME  7615
# Winner is  p1
# GAME  7616
# Winner is  p1
# GAME  7617
# Winner is  p1
# GAME  7618
# Winner is  p1
# GAME  7619
# Winner is  p1
# GAME  7620
# Winner is  p1
# GAME  7621
# Winner is  p1
# GAME  7622
# Winner is  p1
# GAME  7623
# Winner is  p1
# GAME  7624
# Winner is  p1
# GAME  7625
# Winner is  p1
# GAME  7626
# Winner is  p1
# GAME  7627
# Winner is  p1
# GAME  7628
# Winner is  p1
# GAME  7629
# Winner is  p1
# GAME  7630
# Winner is  p1
# GAME  7631
# Winner is  p1
# GAME  7632
# Winner is  p1
# GAME  7633
# Winner is  p1
# GAME  7634
# Winner is  p1
# GAME  7635
# Winner is  p1
# GAME  7636
# Winner is  p1
# GAME  7637
# Winner is  p1
# GAME  7638
# Winner is  p1
# GAME  7639
# Winner is  p1
# GAME  7640
# Winner is  p1
# GAME  7641
# Winner is  p1
# GAME  7642
# Winner is  p1
# GAME  7643
# Winner is  p1
# GAME  7644
# Winner is  p1
# GAME  7645
# Winner is  p1
# GAME  7646
# Winner is  p1
# GAME  7647
# Winner is  p1
# GAME  7648
# Winner is  p1
# GAME  7649
# Winner is  p1
# GAME  7650
# Winner is  p1
# GAME  7651
# Winner is  p1
# GAME  7652
# Winner is  p1
# GAME  7653
# Winner is  p1
# GAME  7654
# Winner is  p1
# GAME  7655
# Winner is  p1
# GAME  7656
# Winner is  p1
# GAME  7657
# Winner is  p1
# GAME  7658
# Winner is  p1
# GAME  7659
# Winner is  p1
# GAME  7660
# Winner is  p1
# GAME  7661
# Winner is  p1
# GAME  7662
# Winner is  p1
# GAME  7663
# Winner is  p1
# GAME  7664
# Winner is  p1
# GAME  7665
# Winner is  p1
# GAME  7666
# Winner is  p1
# GAME  7667
# Winner is  p1
# GAME  7668
# Winner is  p1
# GAME  7669
# Winner is  p1
# GAME  7670
# Winner is  p1
# GAME  7671
# Winner is  p1
# GAME  7672
# Winner is  p1
# GAME  7673
# Winner is  p1
# GAME  7674
# Winner is  p1
# GAME  7675
# Winner is  p1
# GAME  7676
# Winner is  p1
# GAME  7677
# Winner is  p1
# GAME  7678
# Winner is  p1
# GAME  7679
# Winner is  p1
# GAME  7680
# Winner is  p1
# GAME  7681
# Winner is  p1
# GAME  7682
# Winner is  p1
# GAME  7683
# Winner is  p1
# GAME  7684
# Winner is  p1
# GAME  7685
# Winner is  p1
# GAME  7686
# Winner is  p1
# GAME  7687
# Winner is  p1
# GAME  7688
# Winner is  p1
# GAME  7689
# Winner is  p1
# GAME  7690
# Winner is  p1
# GAME  7691
# Winner is  p1
# GAME  7692
# Winner is  p1
# GAME  7693
# Winner is  p1
# GAME  7694
# Winner is  p1
# GAME  7695
# Winner is  p1
# GAME  7696
# Winner is  p1
# GAME  7697
# Winner is  p1
# GAME  7698
# Winner is  p1
# GAME  7699
# Winner is  p1
# GAME  7700
# Winner is  p1
# GAME  7701
# Winner is  p1
# GAME  7702
# Winner is  p1
# GAME  7703
# Winner is  p1
# GAME  7704
# Winner is  p1
# GAME  7705
# Winner is  p1
# GAME  7706
# Winner is  p1
# GAME  7707
# Winner is  p1
# GAME  7708
# Winner is  p1
# GAME  7709
# Winner is  p1
# GAME  7710
# Winner is  p1
# GAME  7711
# Winner is  p1
# GAME  7712
# Winner is  p1
# GAME  7713
# Winner is  p1
# GAME  7714
# Winner is  p1
# GAME  7715
# Winner is  p1
# GAME  7716
# Winner is  p1
# GAME  7717
# Winner is  p1
# GAME  7718
# Winner is  p1
# GAME  7719
# Winner is  p1
# GAME  7720
# Winner is  p1
# GAME  7721
# Winner is  p1
# GAME  7722
# Winner is  p1
# GAME  7723
# Winner is  p1
# GAME  7724
# Winner is  p1
# GAME  7725
# Winner is  p1
# GAME  7726
# Winner is  p1
# GAME  7727
# Winner is  p1
# GAME  7728
# Winner is  p1
# GAME  7729
# Winner is  p1
# GAME  7730
# Winner is  p1
# GAME  7731
# Winner is  p1
# GAME  7732
# Winner is  p1
# GAME  7733
# Winner is  p1
# GAME  7734
# Winner is  p1
# GAME  7735
# Winner is  p1
# GAME  7736
# Winner is  p1
# GAME  7737
# Winner is  p1
# GAME  7738
# Winner is  p1
# GAME  7739
# Winner is  p1
# GAME  7740
# Winner is  p1
# GAME  7741
# Winner is  p1
# GAME  7742
# Winner is  p1
# GAME  7743
# Winner is  p1
# GAME  7744
# Winner is  p1
# GAME  7745
# Winner is  p1
# GAME  7746
# Winner is  p1
# GAME  7747
# Winner is  p1
# GAME  7748
# Winner is  p1
# GAME  7749
# Winner is  p1
# GAME  7750
# Winner is  p1
# GAME  7751
# Winner is  p1
# GAME  7752
# Winner is  p1
# GAME  7753
# Winner is  p1
# GAME  7754
# Winner is  p1
# GAME  7755
# Winner is  p1
# GAME  7756
# Winner is  p1
# GAME  7757
# Winner is  p1
# GAME  7758
# Winner is  p1
# GAME  7759
# Winner is  p1
# GAME  7760
# Winner is  p1
# GAME  7761
# Winner is  p1
# GAME  7762
# Winner is  p1
# GAME  7763
# Winner is  p1
# GAME  7764
# Winner is  p1
# GAME  7765
# Winner is  p1
# GAME  7766
# Winner is  p1
# GAME  7767
# Winner is  p1
# GAME  7768
# Winner is  p1
# GAME  7769
# Winner is  p1
# GAME  7770
# Winner is  p1
# GAME  7771
# Winner is  p1
# GAME  7772
# Winner is  p1
# GAME  7773
# Winner is  p1
# GAME  7774
# Winner is  p1
# GAME  7775
# Winner is  p1
# GAME  7776
# Winner is  p1
# GAME  7777
# Winner is  p1
# GAME  7778
# Winner is  p1
# GAME  7779
# Winner is  p1
# GAME  7780
# Winner is  p1
# GAME  7781
# Winner is  p1
# GAME  7782
# Winner is  p1
# GAME  7783
# Winner is  p1
# GAME  7784
# Winner is  p1
# GAME  7785
# Winner is  p1
# GAME  7786
# Winner is  p1
# GAME  7787
# Winner is  p1
# GAME  7788
# Winner is  p1
# GAME  7789
# Winner is  p1
# GAME  7790
# Winner is  p1
# GAME  7791
# Winner is  p1
# GAME  7792
# Winner is  p1
# GAME  7793
# Winner is  p1
# GAME  7794
# Winner is  p1
# GAME  7795
# Winner is  p1
# GAME  7796
# Winner is  p1
# GAME  7797
# Winner is  p1
# GAME  7798
# Winner is  p1
# GAME  7799
# Winner is  p1
# GAME  7800
# Winner is  p1
# GAME  7801
# Winner is  p1
# GAME  7802
# Winner is  p1
# GAME  7803
# Winner is  p1
# GAME  7804
# Winner is  p1
# GAME  7805
# Winner is  p1
# GAME  7806
# Winner is  p1
# GAME  7807
# Winner is  p1
# GAME  7808
# Winner is  p1
# GAME  7809
# Winner is  p1
# GAME  7810
# Winner is  p1
# GAME  7811
# Winner is  p1
# GAME  7812
# Winner is  p1
# GAME  7813
# Winner is  p1
# GAME  7814
# Winner is  p1
# GAME  7815
# Winner is  p1
# GAME  7816
# Winner is  p1
# GAME  7817
# Winner is  p1
# GAME  7818
# Winner is  p1
# GAME  7819
# Winner is  p1
# GAME  7820
# Winner is  p1
# GAME  7821
# Winner is  p1
# GAME  7822
# Winner is  p1
# GAME  7823
# Winner is  p1
# GAME  7824
# Winner is  p1
# GAME  7825
# Winner is  p1
# GAME  7826
# Winner is  p1
# GAME  7827
# Winner is  p1
# GAME  7828
# Winner is  p1
# GAME  7829
# Winner is  p1
# GAME  7830
# Winner is  p1
# GAME  7831
# Winner is  p1
# GAME  7832
# Winner is  p1
# GAME  7833
# Winner is  p1
# GAME  7834
# Winner is  p1
# GAME  7835
# Winner is  p1
# GAME  7836
# Winner is  p1
# GAME  7837
# Winner is  p1
# GAME  7838
# Winner is  p1
# GAME  7839
# Winner is  p1
# GAME  7840
# Winner is  p1
# GAME  7841
# Winner is  p1
# GAME  7842
# Winner is  p1
# GAME  7843
# Winner is  p1
# GAME  7844
# Winner is  p1
# GAME  7845
# Winner is  p1
# GAME  7846
# Winner is  p1
# GAME  7847
# Winner is  p1
# GAME  7848
# Winner is  p1
# GAME  7849
# Winner is  p1
# GAME  7850
# Winner is  p1
# GAME  7851
# Winner is  p1
# GAME  7852
# Winner is  p1
# GAME  7853
# Winner is  p1
# GAME  7854
# Winner is  p1
# GAME  7855
# Winner is  p1
# GAME  7856
# Winner is  p1
# GAME  7857
# Winner is  p1
# GAME  7858
# Winner is  p1
# GAME  7859
# Winner is  p1
# GAME  7860
# Winner is  p1
# GAME  7861
# Winner is  p1
# GAME  7862
# Winner is  p1
# GAME  7863
# Winner is  p1
# GAME  7864
# Winner is  p1
# GAME  7865
# Winner is  p1
# GAME  7866
# Winner is  p1
# GAME  7867
# Winner is  p1
# GAME  7868
# Winner is  p1
# GAME  7869
# Winner is  p1
# GAME  7870
# Winner is  p1
# GAME  7871
# Winner is  p1
# GAME  7872
# Winner is  p1
# GAME  7873
# Winner is  p1
# GAME  7874
# Winner is  p1
# GAME  7875
# Winner is  p1
# GAME  7876
# Winner is  p1
# GAME  7877
# Winner is  p1
# GAME  7878
# Winner is  p1
# GAME  7879
# Winner is  p1
# GAME  7880
# Winner is  p1
# GAME  7881
# Winner is  p1
# GAME  7882
# Winner is  p1
# GAME  7883
# Winner is  p1
# GAME  7884
# Winner is  p1
# GAME  7885
# Winner is  p1
# GAME  7886
# Winner is  p1
# GAME  7887
# Winner is  p1
# GAME  7888
# Winner is  p1
# GAME  7889
# Winner is  p1
# GAME  7890
# Winner is  p1
# GAME  7891
# Winner is  p1
# GAME  7892
# Winner is  p1
# GAME  7893
# Winner is  p1
# GAME  7894
# Winner is  p1
# GAME  7895
# Winner is  p1
# GAME  7896
# Winner is  p1
# GAME  7897
# Winner is  p1
# GAME  7898
# Winner is  p1
# GAME  7899
# Winner is  p1
# GAME  7900
# Winner is  p1
# GAME  7901
# Winner is  p1
# GAME  7902
# Winner is  p1
# GAME  7903
# Winner is  p1
# GAME  7904
# Winner is  p1
# GAME  7905
# Winner is  p1
# GAME  7906
# Winner is  p1
# GAME  7907
# Winner is  p1
# GAME  7908
# Winner is  p1
# GAME  7909
# Winner is  p1
# GAME  7910
# Winner is  p1
# GAME  7911
# Winner is  p1
# GAME  7912
# Winner is  p1
# GAME  7913
# Winner is  p1
# GAME  7914
# Winner is  p1
# GAME  7915
# Winner is  p1
# GAME  7916
# Winner is  p1
# GAME  7917
# Winner is  p1
# GAME  7918
# Winner is  p1
# GAME  7919
# Winner is  p1
# GAME  7920
# Winner is  p1
# GAME  7921
# Winner is  p1
# GAME  7922
# Winner is  p1
# GAME  7923
# Winner is  p1
# GAME  7924
# Winner is  p1
# GAME  7925
# Winner is  p1
# GAME  7926
# Winner is  p1
# GAME  7927
# Winner is  p1
# GAME  7928
# Winner is  p1
# GAME  7929
# Winner is  p1
# GAME  7930
# Winner is  p1
# GAME  7931
# Winner is  p1
# GAME  7932
# Winner is  p1
# GAME  7933
# Winner is  p1
# GAME  7934
# Winner is  p1
# GAME  7935
# Winner is  p1
# GAME  7936
# Winner is  p1
# GAME  7937
# Winner is  p1
# GAME  7938
# Winner is  p1
# GAME  7939
# Winner is  p1
# GAME  7940
# Winner is  p1
# GAME  7941
# Winner is  p1
# GAME  7942
# Winner is  p1
# GAME  7943
# Winner is  p1
# GAME  7944
# Winner is  p1
# GAME  7945
# Winner is  p1
# GAME  7946
# Winner is  p1
# GAME  7947
# Winner is  p1
# GAME  7948
# Winner is  p1
# GAME  7949
# Winner is  p1
# GAME  7950
# Winner is  p1
# GAME  7951
# Winner is  p1
# GAME  7952
# Winner is  p1
# GAME  7953
# Winner is  p1
# GAME  7954
# Winner is  p1
# GAME  7955
# Winner is  p1
# GAME  7956
# Winner is  p1
# GAME  7957
# Winner is  p1
# GAME  7958
# Winner is  p1
# GAME  7959
# Winner is  p1
# GAME  7960
# Winner is  p1
# GAME  7961
# Winner is  p1
# GAME  7962
# Winner is  p1
# GAME  7963
# Winner is  p1
# GAME  7964
# Winner is  p1
# GAME  7965
# Winner is  p1
# GAME  7966
# Winner is  p1
# GAME  7967
# Winner is  p1
# GAME  7968
# Winner is  p1
# GAME  7969
# Winner is  p1
# GAME  7970
# Winner is  p1
# GAME  7971
# Winner is  p1
# GAME  7972
# Winner is  p1
# GAME  7973
# Winner is  p1
# GAME  7974
# Winner is  p1
# GAME  7975
# Winner is  p1
# GAME  7976
# Winner is  p1
# GAME  7977
# Winner is  p1
# GAME  7978
# Winner is  p1
# GAME  7979
# Winner is  p1
# GAME  7980
# Winner is  p1
# GAME  7981
# Winner is  p1
# GAME  7982
# Winner is  p1
# GAME  7983
# Winner is  p1
# GAME  7984
# Winner is  p1
# GAME  7985
# Winner is  p1
# GAME  7986
# Winner is  p1
# GAME  7987
# Winner is  p1
# GAME  7988
# Winner is  p1
# GAME  7989
# Winner is  p1
# GAME  7990
# Winner is  p1
# GAME  7991
# Winner is  p1
# GAME  7992
# Winner is  p1
# GAME  7993
# Winner is  p1
# GAME  7994
# Winner is  p1
# GAME  7995
# Winner is  p1
# GAME  7996
# Winner is  p1
# GAME  7997
# Winner is  p1
# GAME  7998
# Winner is  p1
# GAME  7999
# Winner is  p1
# GAME  8000
# Winner is  p1
# GAME  8001
# Winner is  p1
# GAME  8002
# Winner is  p1
# GAME  8003
# Winner is  p1
# GAME  8004
# Winner is  p1
# GAME  8005
# Winner is  p1
# GAME  8006
# Winner is  p1
# GAME  8007
# Winner is  p1
# GAME  8008
# Winner is  p1
# GAME  8009
# Winner is  p1
# GAME  8010
# Winner is  p1
# GAME  8011
# Winner is  p1
# GAME  8012
# Winner is  p1
# GAME  8013
# Winner is  p1
# GAME  8014
# Winner is  p1
# GAME  8015
# Winner is  p1
# GAME  8016
# Winner is  p1
# GAME  8017
# Winner is  p1
# GAME  8018
# Winner is  p1
# GAME  8019
# Winner is  p1
# GAME  8020
# Winner is  p1
# GAME  8021
# Winner is  p1
# GAME  8022
# Winner is  p1
# GAME  8023
# Winner is  p1
# GAME  8024
# Winner is  p1
# GAME  8025
# Winner is  p1
# GAME  8026
# Winner is  p1
# GAME  8027
# Winner is  p1
# GAME  8028
# Winner is  p1
# GAME  8029
# Winner is  p1
# GAME  8030
# Winner is  p1
# GAME  8031
# Winner is  p1
# GAME  8032
# Winner is  p1
# GAME  8033
# Winner is  p1
# GAME  8034
# Winner is  p1
# GAME  8035
# Winner is  p1
# GAME  8036
# Winner is  p1
# GAME  8037
# Winner is  p1
# GAME  8038
# Winner is  p1
# GAME  8039
# Winner is  p1
# GAME  8040
# Winner is  p1
# GAME  8041
# Winner is  p1
# GAME  8042
# Winner is  p1
# GAME  8043
# Winner is  p1
# GAME  8044
# Winner is  p1
# GAME  8045
# Winner is  p1
# GAME  8046
# Winner is  p1
# GAME  8047
# Winner is  p1
# GAME  8048
# Winner is  p1
# GAME  8049
# Winner is  p1
# GAME  8050
# Winner is  p1
# GAME  8051
# Winner is  p1
# GAME  8052
# Winner is  p1
# GAME  8053
# Winner is  p1
# GAME  8054
# Winner is  p1
# GAME  8055
# Winner is  p1
# GAME  8056
# Winner is  p1
# GAME  8057
# Winner is  p1
# GAME  8058
# Winner is  p1
# GAME  8059
# Winner is  p1
# GAME  8060
# Winner is  p1
# GAME  8061
# Winner is  p1
# GAME  8062
# Winner is  p1
# GAME  8063
# Winner is  p1
# GAME  8064
# Winner is  p1
# GAME  8065
# Winner is  p1
# GAME  8066
# Winner is  p1
# GAME  8067
# Winner is  p1
# GAME  8068
# Winner is  p1
# GAME  8069
# Winner is  p1
# GAME  8070
# Winner is  p1
# GAME  8071
# Winner is  p1
# GAME  8072
# Winner is  p1
# GAME  8073
# Winner is  p1
# GAME  8074
# Winner is  p1
# GAME  8075
# Winner is  p1
# GAME  8076
# Winner is  p1
# GAME  8077
# Winner is  p1
# GAME  8078
# Winner is  p1
# GAME  8079
# Winner is  p1
# GAME  8080
# Winner is  p1
# GAME  8081
# Winner is  p1
# GAME  8082
# Winner is  p1
# GAME  8083
# Winner is  p1
# GAME  8084
# Winner is  p1
# GAME  8085
# Winner is  p1
# GAME  8086
# Winner is  p1
# GAME  8087
# Winner is  p1
# GAME  8088
# Winner is  p1
# GAME  8089
# Winner is  p1
# GAME  8090
# Winner is  p1
# GAME  8091
# Winner is  p1
# GAME  8092
# Winner is  p1
# GAME  8093
# Winner is  p1
# GAME  8094
# Winner is  p1
# GAME  8095
# Winner is  p1
# GAME  8096
# Winner is  p1
# GAME  8097
# Winner is  p1
# GAME  8098
# Winner is  p1
# GAME  8099
# Winner is  p1
# GAME  8100
# Winner is  p1
# GAME  8101
# Winner is  p1
# GAME  8102
# Winner is  p1
# GAME  8103
# Winner is  p1
# GAME  8104
# Winner is  p1
# GAME  8105
# Winner is  p1
# GAME  8106
# Winner is  p1
# GAME  8107
# Winner is  p1
# GAME  8108
# Winner is  p1
# GAME  8109
# Winner is  p1
# GAME  8110
# Winner is  p1
# GAME  8111
# Winner is  p1
# GAME  8112
# Winner is  p1
# GAME  8113
# Winner is  p1
# GAME  8114
# Winner is  p1
# GAME  8115
# Winner is  p1
# GAME  8116
# Winner is  p1
# GAME  8117
# Winner is  p1
# GAME  8118
# Winner is  p1
# GAME  8119
# Winner is  p1
# GAME  8120
# Winner is  p1
# GAME  8121
# Winner is  p1
# GAME  8122
# Winner is  p1
# GAME  8123
# Winner is  p1
# GAME  8124
# Winner is  p1
# GAME  8125
# Winner is  p1
# GAME  8126
# Winner is  p1
# GAME  8127
# Winner is  p1
# GAME  8128
# Winner is  p1
# GAME  8129
# Winner is  p1
# GAME  8130
# Winner is  p1
# GAME  8131
# Winner is  p1
# GAME  8132
# Winner is  p1
# GAME  8133
# Winner is  p1
# GAME  8134
# Winner is  p1
# GAME  8135
# Winner is  p1
# GAME  8136
# Winner is  p1
# GAME  8137
# Winner is  p1
# GAME  8138
# Winner is  p1
# GAME  8139
# Winner is  p1
# GAME  8140
# Winner is  p1
# GAME  8141
# Winner is  p1
# GAME  8142
# Winner is  p1
# GAME  8143
# Winner is  p1
# GAME  8144
# Winner is  p1
# GAME  8145
# Winner is  p1
# GAME  8146
# Winner is  p1
# GAME  8147
# Winner is  p1
# GAME  8148
# Winner is  p1
# GAME  8149
# Winner is  p1
# GAME  8150
# Winner is  p1
# GAME  8151
# Winner is  p1
# GAME  8152
# Winner is  p1
# GAME  8153
# Winner is  p1
# GAME  8154
# Winner is  p1
# GAME  8155
# Winner is  p1
# GAME  8156
# Winner is  p1
# GAME  8157
# Winner is  p1
# GAME  8158
# Winner is  p1
# GAME  8159
# Winner is  p1
# GAME  8160
# Winner is  p1
# GAME  8161
# Winner is  p1
# GAME  8162
# Winner is  p1
# GAME  8163
# Winner is  p1
# GAME  8164
# Winner is  p1
# GAME  8165
# Winner is  p1
# GAME  8166
# Winner is  p1
# GAME  8167
# Winner is  p1
# GAME  8168
# Winner is  p1
# GAME  8169
# Winner is  p1
# GAME  8170
# Winner is  p1
# GAME  8171
# Winner is  p1
# GAME  8172
# Winner is  p1
# GAME  8173
# Winner is  p1
# GAME  8174
# Winner is  p1
# GAME  8175
# Winner is  p1
# GAME  8176
# Winner is  p1
# GAME  8177
# Winner is  p1
# GAME  8178
# Winner is  p1
# GAME  8179
# Winner is  p1
# GAME  8180
# Winner is  p1
# GAME  8181
# Winner is  p1
# GAME  8182
# Winner is  p1
# GAME  8183
# Winner is  p1
# GAME  8184
# Winner is  p1
# GAME  8185
# Winner is  p1
# GAME  8186
# Winner is  p1
# GAME  8187
# Winner is  p1
# GAME  8188
# Winner is  p1
# GAME  8189
# Winner is  p1
# GAME  8190
# Winner is  p1
# GAME  8191
# Winner is  p1
# GAME  8192
# Winner is  p1
# GAME  8193
# Winner is  p1
# GAME  8194
# Winner is  p1
# GAME  8195
# Winner is  p1
# GAME  8196
# Winner is  p1
# GAME  8197
# Winner is  p1
# GAME  8198
# Winner is  p1
# GAME  8199
# Winner is  p1
# GAME  8200
# Winner is  p1
# GAME  8201
# Winner is  p1
# GAME  8202
# Winner is  p1
# GAME  8203
# Winner is  p1
# GAME  8204
# Winner is  p1
# GAME  8205
# Winner is  p1
# GAME  8206
# Winner is  p1
# GAME  8207
# Winner is  p1
# GAME  8208
# Winner is  p1
# GAME  8209
# Winner is  p1
# GAME  8210
# Winner is  p1
# GAME  8211
# Winner is  p1
# GAME  8212
# Winner is  p1
# GAME  8213
# Winner is  p1
# GAME  8214
# Winner is  p1
# GAME  8215
# Winner is  p1
# GAME  8216
# Winner is  p1
# GAME  8217
# Winner is  p1
# GAME  8218
# Winner is  p1
# GAME  8219
# Winner is  p1
# GAME  8220
# Winner is  p1
# GAME  8221
# Winner is  p1
# GAME  8222
# Winner is  p1
# GAME  8223
# Winner is  p1
# GAME  8224
# Winner is  p1
# GAME  8225
# Winner is  p1
# GAME  8226
# Winner is  p1
# GAME  8227
# Winner is  p1
# GAME  8228
# Winner is  p1
# GAME  8229
# Winner is  p1
# GAME  8230
# Winner is  p1
# GAME  8231
# Winner is  p1
# GAME  8232
# Winner is  p1
# GAME  8233
# Winner is  p1
# GAME  8234
# Winner is  p1
# GAME  8235
# Winner is  p1
# GAME  8236
# Winner is  p1
# GAME  8237
# Winner is  p1
# GAME  8238
# Winner is  p1
# GAME  8239
# Winner is  p1
# GAME  8240
# Winner is  p1
# GAME  8241
# Winner is  p1
# GAME  8242
# Winner is  p1
# GAME  8243
# Winner is  p1
# GAME  8244
# Winner is  p1
# GAME  8245
# Winner is  p1
# GAME  8246
# Winner is  p1
# GAME  8247
# Winner is  p1
# GAME  8248
# Winner is  p1
# GAME  8249
# Winner is  p1
# GAME  8250
# Winner is  p1
# GAME  8251
# Winner is  p1
# GAME  8252
# Winner is  p1
# GAME  8253
# Winner is  p1
# GAME  8254
# Winner is  p1
# GAME  8255
# Winner is  p1
# GAME  8256
# Winner is  p1
# GAME  8257
# Winner is  p1
# GAME  8258
# Winner is  p1
# GAME  8259
# Winner is  p1
# GAME  8260
# Winner is  p1
# GAME  8261
# Winner is  p1
# GAME  8262
# Winner is  p1
# GAME  8263
# Winner is  p1
# GAME  8264
# Winner is  p1
# GAME  8265
# Winner is  p1
# GAME  8266
# Winner is  p1
# GAME  8267
# Winner is  p1
# GAME  8268
# Winner is  p1
# GAME  8269
# Winner is  p1
# GAME  8270
# Winner is  p1
# GAME  8271
# Winner is  p1
# GAME  8272
# Winner is  p1
# GAME  8273
# Winner is  p1
# GAME  8274
# Winner is  p1
# GAME  8275
# Winner is  p1
# GAME  8276
# Winner is  p1
# GAME  8277
# Winner is  p1
# GAME  8278
# Winner is  p1
# GAME  8279
# Winner is  p1
# GAME  8280
# Winner is  p1
# GAME  8281
# Winner is  p1
# GAME  8282
# Winner is  p1
# GAME  8283
# Winner is  p1
# GAME  8284
# Winner is  p1
# GAME  8285
# Winner is  p1
# GAME  8286
# Winner is  p1
# GAME  8287
# Winner is  p1
# GAME  8288
# Winner is  p1
# GAME  8289
# Winner is  p1
# GAME  8290
# Winner is  p1
# GAME  8291
# Winner is  p1
# GAME  8292
# Winner is  p1
# GAME  8293
# Winner is  p1
# GAME  8294
# Winner is  p1
# GAME  8295
# Winner is  p1
# GAME  8296
# Winner is  p1
# GAME  8297
# Winner is  p1
# GAME  8298
# Winner is  p1
# GAME  8299
# Winner is  p1
# GAME  8300
# Winner is  p1
# GAME  8301
# Winner is  p1
# GAME  8302
# Winner is  p1
# GAME  8303
# Winner is  p1
# GAME  8304
# Winner is  p1
# GAME  8305
# Winner is  p1
# GAME  8306
# Winner is  p1
# GAME  8307
# Winner is  p1
# GAME  8308
# Winner is  p1
# GAME  8309
# Winner is  p1
# GAME  8310
# Winner is  p1
# GAME  8311
# Winner is  p1
# GAME  8312
# Winner is  p1
# GAME  8313
# Winner is  p1
# GAME  8314
# Winner is  p1
# GAME  8315
# Winner is  p1
# GAME  8316
# Winner is  p1
# GAME  8317
# Winner is  p1
# GAME  8318
# Winner is  p1
# GAME  8319
# Winner is  p1
# GAME  8320
# Winner is  p1
# GAME  8321
# Winner is  p1
# GAME  8322
# Winner is  p1
# GAME  8323
# Winner is  p1
# GAME  8324
# Winner is  p1
# GAME  8325
# Winner is  p1
# GAME  8326
# Winner is  p1
# GAME  8327
# Winner is  p1
# GAME  8328
# Winner is  p1
# GAME  8329
# Winner is  p1
# GAME  8330
# Winner is  p1
# GAME  8331
# Winner is  p1
# GAME  8332
# Winner is  p1
# GAME  8333
# Winner is  p1
# GAME  8334
# Winner is  p1
# GAME  8335
# Winner is  p1
# GAME  8336
# Winner is  p1
# GAME  8337
# Winner is  p1
# GAME  8338
# Winner is  p1
# GAME  8339
# Winner is  p1
# GAME  8340
# Winner is  p1
# GAME  8341
# Winner is  p1
# GAME  8342
# Winner is  p1
# GAME  8343
# Winner is  p1
# GAME  8344
# Winner is  p1
# GAME  8345
# Winner is  p1
# GAME  8346
# Winner is  p1
# GAME  8347
# Winner is  p1
# GAME  8348
# Winner is  p1
# GAME  8349
# Winner is  p1
# GAME  8350
# Winner is  p1
# GAME  8351
# Winner is  p1
# GAME  8352
# Winner is  p1
# GAME  8353
# Winner is  p1
# GAME  8354
# Winner is  p1
# GAME  8355
# Winner is  p1
# GAME  8356
# Winner is  p1
# GAME  8357
# Winner is  p1
# GAME  8358
# Winner is  p1
# GAME  8359
# Winner is  p1
# GAME  8360
# Winner is  p1
# GAME  8361
# Winner is  p1
# GAME  8362
# Winner is  p1
# GAME  8363
# Winner is  p1
# GAME  8364
# Winner is  p1
# GAME  8365
# Winner is  p1
# GAME  8366
# Winner is  p1
# GAME  8367
# Winner is  p1
# GAME  8368
# Winner is  p1
# GAME  8369
# Winner is  p1
# GAME  8370
# Winner is  p1
# GAME  8371
# Winner is  p1
# GAME  8372
# Winner is  p1
# GAME  8373
# Winner is  p1
# GAME  8374
# Winner is  p1
# GAME  8375
# Winner is  p1
# GAME  8376
# Winner is  p1
# GAME  8377
# Winner is  p1
# GAME  8378
# Winner is  p1
# GAME  8379
# Winner is  p1
# GAME  8380
# Winner is  p1
# GAME  8381
# Winner is  p1
# GAME  8382
# Winner is  p1
# GAME  8383
# Winner is  p1
# GAME  8384
# Winner is  p1
# GAME  8385
# Winner is  p1
# GAME  8386
# Winner is  p1
# GAME  8387
# Winner is  p1
# GAME  8388
# Winner is  p1
# GAME  8389
# Winner is  p1
# GAME  8390
# Winner is  p1
# GAME  8391
# Winner is  p1
# GAME  8392
# Winner is  p1
# GAME  8393
# Winner is  p1
# GAME  8394
# Winner is  p1
# GAME  8395
# Winner is  p1
# GAME  8396
# Winner is  p1
# GAME  8397
# Winner is  p1
# GAME  8398
# Winner is  p1
# GAME  8399
# Winner is  p1
# GAME  8400
# Winner is  p1
# GAME  8401
# Winner is  p1
# GAME  8402
# Winner is  p1
# GAME  8403
# Winner is  p1
# GAME  8404
# Winner is  p1
# GAME  8405
# Winner is  p1
# GAME  8406
# Winner is  p1
# GAME  8407
# Winner is  p1
# GAME  8408
# Winner is  p1
# GAME  8409
# Winner is  p1
# GAME  8410
# Winner is  p1
# GAME  8411
# Winner is  p1
# GAME  8412
# Winner is  p1
# GAME  8413
# Winner is  p1
# GAME  8414
# Winner is  p1
# GAME  8415
# Winner is  p1
# GAME  8416
# Winner is  p1
# GAME  8417
# Winner is  p1
# GAME  8418
# Winner is  p1
# GAME  8419
# Winner is  p1
# GAME  8420
# Winner is  p1
# GAME  8421
# Winner is  p1
# GAME  8422
# Winner is  p1
# GAME  8423
# Winner is  p1
# GAME  8424
# Winner is  p1
# GAME  8425
# Winner is  p1
# GAME  8426
# Winner is  p1
# GAME  8427
# Winner is  p1
# GAME  8428
# Winner is  p1
# GAME  8429
# Winner is  p1
# GAME  8430
# Winner is  p1
# GAME  8431
# Winner is  p1
# GAME  8432
# Winner is  p1
# GAME  8433
# Winner is  p1
# GAME  8434
# Winner is  p1
# GAME  8435
# Winner is  p1
# GAME  8436
# Winner is  p1
# GAME  8437
# Winner is  p1
# GAME  8438
# Winner is  p1
# GAME  8439
# Winner is  p1
# GAME  8440
# Winner is  p1
# GAME  8441
# Winner is  p1
# GAME  8442
# Winner is  p1
# GAME  8443
# Winner is  p1
# GAME  8444
# Winner is  p1
# GAME  8445
# Winner is  p1
# GAME  8446
# Winner is  p1
# GAME  8447
# Winner is  p1
# GAME  8448
# Winner is  p1
# GAME  8449
# Winner is  p1
# GAME  8450
# Winner is  p1
# GAME  8451
# Winner is  p1
# GAME  8452
# Winner is  p1
# GAME  8453
# Winner is  p1
# GAME  8454
# Winner is  p1
# GAME  8455
# Winner is  p1
# GAME  8456
# Winner is  p1
# GAME  8457
# Winner is  p1
# GAME  8458
# Winner is  p1
# GAME  8459
# Winner is  p1
# GAME  8460
# Winner is  p1
# GAME  8461
# Winner is  p1
# GAME  8462
# Winner is  p1
# GAME  8463
# Winner is  p1
# GAME  8464
# Winner is  p1
# GAME  8465
# Winner is  p1
# GAME  8466
# Winner is  p1
# GAME  8467
# Winner is  p1
# GAME  8468
# Winner is  p1
# GAME  8469
# Winner is  p1
# GAME  8470
# Winner is  p1
# GAME  8471
# Winner is  p1
# GAME  8472
# Winner is  p1
# GAME  8473
# Winner is  p1
# GAME  8474
# Winner is  p1
# GAME  8475
# Winner is  p1
# GAME  8476
# Winner is  p1
# GAME  8477
# Winner is  p1
# GAME  8478
# Winner is  p1
# GAME  8479
# Winner is  p1
# GAME  8480
# Winner is  p1
# GAME  8481
# Winner is  p1
# GAME  8482
# Winner is  p1
# GAME  8483
# Winner is  p1
# GAME  8484
# Winner is  p1
# GAME  8485
# Winner is  p1
# GAME  8486
# Winner is  p1
# GAME  8487
# Winner is  p1
# GAME  8488
# Winner is  p1
# GAME  8489
# Winner is  p1
# GAME  8490
# Winner is  p1
# GAME  8491
# Winner is  p1
# GAME  8492
# Winner is  p1
# GAME  8493
# Winner is  p1
# GAME  8494
# Winner is  p1
# GAME  8495
# Winner is  p1
# GAME  8496
# Winner is  p1
# GAME  8497
# Winner is  p1
# GAME  8498
# Winner is  p1
# GAME  8499
# Winner is  p1
# GAME  8500
# Winner is  p1
# GAME  8501
# Winner is  p1
# GAME  8502
# Winner is  p1
# GAME  8503
# Winner is  p1
# GAME  8504
# Winner is  p1
# GAME  8505
# Winner is  p1
# GAME  8506
# Winner is  p1
# GAME  8507
# Winner is  p1
# GAME  8508
# Winner is  p1
# GAME  8509
# Winner is  p1
# GAME  8510
# Winner is  p1
# GAME  8511
# Winner is  p1
# GAME  8512
# Winner is  p1
# GAME  8513
# Winner is  p1
# GAME  8514
# Winner is  p1
# GAME  8515
# Winner is  p1
# GAME  8516
# Winner is  p1
# GAME  8517
# Winner is  p1
# GAME  8518
# Winner is  p1
# GAME  8519
# Winner is  p1
# GAME  8520
# Winner is  p1
# GAME  8521
# Winner is  p1
# GAME  8522
# Winner is  p1
# GAME  8523
# Winner is  p1
# GAME  8524
# Winner is  p1
# GAME  8525
# Winner is  p1
# GAME  8526
# Winner is  p1
# GAME  8527
# Winner is  p1
# GAME  8528
# Winner is  p1
# GAME  8529
# Winner is  p1
# GAME  8530
# Winner is  p1
# GAME  8531
# Winner is  p1
# GAME  8532
# Winner is  p1
# GAME  8533
# Winner is  p1
# GAME  8534
# Winner is  p1
# GAME  8535
# Winner is  p1
# GAME  8536
# Winner is  p1
# GAME  8537
# Winner is  p1
# GAME  8538
# Winner is  p1
# GAME  8539
# Winner is  p1
# GAME  8540
# Winner is  p1
# GAME  8541
# Winner is  p1
# GAME  8542
# Winner is  p1
# GAME  8543
# Winner is  p1
# GAME  8544
# Winner is  p1
# GAME  8545
# Winner is  p1
# GAME  8546
# Winner is  p1
# GAME  8547
# Winner is  p1
# GAME  8548
# Winner is  p1
# GAME  8549
# Winner is  p1
# GAME  8550
# Winner is  p1
# GAME  8551
# Winner is  p1
# GAME  8552
# Winner is  p1
# GAME  8553
# Winner is  p1
# GAME  8554
# Winner is  p1
# GAME  8555
# Winner is  p1
# GAME  8556
# Winner is  p1
# GAME  8557
# Winner is  p1
# GAME  8558
# Winner is  p1
# GAME  8559
# Winner is  p1
# GAME  8560
# Winner is  p1
# GAME  8561
# Winner is  p1
# GAME  8562
# Winner is  p1
# GAME  8563
# Winner is  p1
# GAME  8564
# Winner is  p1
# GAME  8565
# Winner is  p1
# GAME  8566
# Winner is  p1
# GAME  8567
# Winner is  p1
# GAME  8568
# Winner is  p1
# GAME  8569
# Winner is  p1
# GAME  8570
# Winner is  p1
# GAME  8571
# Winner is  p1
# GAME  8572
# Winner is  p1
# GAME  8573
# Winner is  p1
# GAME  8574
# Winner is  p1
# GAME  8575
# Winner is  p1
# GAME  8576
# Winner is  p1
# GAME  8577
# Winner is  p1
# GAME  8578
# Winner is  p1
# GAME  8579
# Winner is  p1
# GAME  8580
# Winner is  p1
# GAME  8581
# Winner is  p1
# GAME  8582
# Winner is  p1
# GAME  8583
# Winner is  p1
# GAME  8584
# Winner is  p1
# GAME  8585
# Winner is  p1
# GAME  8586
# Winner is  p1
# GAME  8587
# Winner is  p1
# GAME  8588
# Winner is  p1
# GAME  8589
# Winner is  p1
# GAME  8590
# Winner is  p1
# GAME  8591
# Winner is  p1
# GAME  8592
# Winner is  p1
# GAME  8593
# Winner is  p1
# GAME  8594
# Winner is  p1
# GAME  8595
# Winner is  p1
# GAME  8596
# Winner is  p1
# GAME  8597
# Winner is  p1
# GAME  8598
# Winner is  p1
# GAME  8599
# Winner is  p1
# GAME  8600
# Winner is  p1
# GAME  8601
# Winner is  p1
# GAME  8602
# Winner is  p1
# GAME  8603
# Winner is  p1
# GAME  8604
# Winner is  p1
# GAME  8605
# Winner is  p1
# GAME  8606
# Winner is  p1
# GAME  8607
# Winner is  p1
# GAME  8608
# Winner is  p1
# GAME  8609
# Winner is  p1
# GAME  8610
# Winner is  p1
# GAME  8611
# Winner is  p1
# GAME  8612
# Winner is  p1
# GAME  8613
# Winner is  p1
# GAME  8614
# Winner is  p1
# GAME  8615
# Winner is  p1
# GAME  8616
# Winner is  p1
# GAME  8617
# Winner is  p1
# GAME  8618
# Winner is  p1
# GAME  8619
# Winner is  p1
# GAME  8620
# Winner is  p1
# GAME  8621
# Winner is  p1
# GAME  8622
# Winner is  p1
# GAME  8623
# Winner is  p1
# GAME  8624
# Winner is  p1
# GAME  8625
# Winner is  p1
# GAME  8626
# Winner is  p1
# GAME  8627
# Winner is  p1
# GAME  8628
# Winner is  p1
# GAME  8629
# Winner is  p1
# GAME  8630
# Winner is  p1
# GAME  8631
# Winner is  p1
# GAME  8632
# Winner is  p1
# GAME  8633
# Winner is  p1
# GAME  8634
# Winner is  p1
# GAME  8635
# Winner is  p1
# GAME  8636
# Winner is  p1
# GAME  8637
# Winner is  p1
# GAME  8638
# Winner is  p1
# GAME  8639
# Winner is  p1
# GAME  8640
# Winner is  p1
# GAME  8641
# Winner is  p1
# GAME  8642
# Winner is  p1
# GAME  8643
# Winner is  p1
# GAME  8644
# Winner is  p1
# GAME  8645
# Winner is  p1
# GAME  8646
# Winner is  p1
# GAME  8647
# Winner is  p1
# GAME  8648
# Winner is  p1
# GAME  8649
# Winner is  p1
# GAME  8650
# Winner is  p1
# GAME  8651
# Winner is  p1
# GAME  8652
# Winner is  p1
# GAME  8653
# Winner is  p1
# GAME  8654
# Winner is  p1
# GAME  8655
# Winner is  p1
# GAME  8656
# Winner is  p1
# GAME  8657
# Winner is  p1
# GAME  8658
# Winner is  p1
# GAME  8659
# Winner is  p1
# GAME  8660
# Winner is  p1
# GAME  8661
# Winner is  p1
# GAME  8662
# Winner is  p1
# GAME  8663
# Winner is  p1
# GAME  8664
# Winner is  p1
# GAME  8665
# Winner is  p1
# GAME  8666
# Winner is  p1
# GAME  8667
# Winner is  p1
# GAME  8668
# Winner is  p1
# GAME  8669
# Winner is  p1
# GAME  8670
# Winner is  p1
# GAME  8671
# Winner is  p1
# GAME  8672
# Winner is  p1
# GAME  8673
# Winner is  p1
# GAME  8674
# Winner is  p1
# GAME  8675
# Winner is  p1
# GAME  8676
# Winner is  p1
# GAME  8677
# Winner is  p1
# GAME  8678
# Winner is  p1
# GAME  8679
# Winner is  p1
# GAME  8680
# Winner is  p1
# GAME  8681
# Winner is  p1
# GAME  8682
# Winner is  p1
# GAME  8683
# Winner is  p1
# GAME  8684
# Winner is  p1
# GAME  8685
# Winner is  p1
# GAME  8686
# Winner is  p1
# GAME  8687
# Winner is  p1
# GAME  8688
# Winner is  p1
# GAME  8689
# Winner is  p1
# GAME  8690
# Winner is  p1
# GAME  8691
# Winner is  p1
# GAME  8692
# Winner is  p1
# GAME  8693
# Winner is  p1
# GAME  8694
# Winner is  p1
# GAME  8695
# Winner is  p1
# GAME  8696
# Winner is  p1
# GAME  8697
# Winner is  p1
# GAME  8698
# Winner is  p1
# GAME  8699
# Winner is  p1
# GAME  8700
# Winner is  p1
# GAME  8701
# Winner is  p1
# GAME  8702
# Winner is  p1
# GAME  8703
# Winner is  p1
# GAME  8704
# Winner is  p1
# GAME  8705
# Winner is  p1
# GAME  8706
# Winner is  p1
# GAME  8707
# Winner is  p1
# GAME  8708
# Winner is  p1
# GAME  8709
# Winner is  p1
# GAME  8710
# Winner is  p1
# GAME  8711
# Winner is  p1
# GAME  8712
# Winner is  p1
# GAME  8713
# Winner is  p1
# GAME  8714
# Winner is  p1
# GAME  8715
# Winner is  p1
# GAME  8716
# Winner is  p1
# GAME  8717
# Winner is  p1
# GAME  8718
# Winner is  p1
# GAME  8719
# Winner is  p1
# GAME  8720
# Winner is  p1
# GAME  8721
# Winner is  p1
# GAME  8722
# Winner is  p1
# GAME  8723
# Winner is  p1
# GAME  8724
# Winner is  p1
# GAME  8725
# Winner is  p1
# GAME  8726
# Winner is  p1
# GAME  8727
# Winner is  p1
# GAME  8728
# Winner is  p1
# GAME  8729
# Winner is  p1
# GAME  8730
# Winner is  p1
# GAME  8731
# Winner is  p1
# GAME  8732
# Winner is  p1
# GAME  8733
# Winner is  p1
# GAME  8734
# Winner is  p1
# GAME  8735
# Winner is  p1
# GAME  8736
# Winner is  p1
# GAME  8737
# Winner is  p1
# GAME  8738
# Winner is  p1
# GAME  8739
# Winner is  p1
# GAME  8740
# Winner is  p1
# GAME  8741
# Winner is  p1
# GAME  8742
# Winner is  p1
# GAME  8743
# Winner is  p1
# GAME  8744
# Winner is  p1
# GAME  8745
# Winner is  p1
# GAME  8746
# Winner is  p1
# GAME  8747
# Winner is  p1
# GAME  8748
# Winner is  p1
# GAME  8749
# Winner is  p1
# GAME  8750
# Winner is  p1
# GAME  8751
# Winner is  p1
# GAME  8752
# Winner is  p1
# GAME  8753
# Winner is  p1
# GAME  8754
# Winner is  p1
# GAME  8755
# Winner is  p1
# GAME  8756
# Winner is  p1
# GAME  8757
# Winner is  p1
# GAME  8758
# Winner is  p1
# GAME  8759
# Winner is  p1
# GAME  8760
# Winner is  p1
# GAME  8761
# Winner is  p1
# GAME  8762
# Winner is  p1
# GAME  8763
# Winner is  p1
# GAME  8764
# Winner is  p1
# GAME  8765
# Winner is  p1
# GAME  8766
# Winner is  p1
# GAME  8767
# Winner is  p1
# GAME  8768
# Winner is  p1
# GAME  8769
# Winner is  p1
# GAME  8770
# Winner is  p1
# GAME  8771
# Winner is  p1
# GAME  8772
# Winner is  p1
# GAME  8773
# Winner is  p1
# GAME  8774
# Winner is  p1
# GAME  8775
# Winner is  p1
# GAME  8776
# Winner is  p1
# GAME  8777
# Winner is  p1
# GAME  8778
# Winner is  p1
# GAME  8779
# Winner is  p1
# GAME  8780
# Winner is  p1
# GAME  8781
# Winner is  p1
# GAME  8782
# Winner is  p1
# GAME  8783
# Winner is  p1
# GAME  8784
# Winner is  p1
# GAME  8785
# Winner is  p1
# GAME  8786
# Winner is  p1
# GAME  8787
# Winner is  p1
# GAME  8788
# Winner is  p1
# GAME  8789
# Winner is  p1
# GAME  8790
# Winner is  p1
# GAME  8791
# Winner is  p1
# GAME  8792
# Winner is  p1
# GAME  8793
# Winner is  p1
# GAME  8794
# Winner is  p1
# GAME  8795
# Winner is  p1
# GAME  8796
# Winner is  p1
# GAME  8797
# Winner is  p1
# GAME  8798
# Winner is  p1
# GAME  8799
# Winner is  p1
# GAME  8800
# Winner is  p1
# GAME  8801
# Winner is  p1
# GAME  8802
# Winner is  p1
# GAME  8803
# Winner is  p1
# GAME  8804
# Winner is  p1
# GAME  8805
# Winner is  p1
# GAME  8806
# Winner is  p1
# GAME  8807
# Winner is  p1
# GAME  8808
# Winner is  p1
# GAME  8809
# Winner is  p1
# GAME  8810
# Winner is  p1
# GAME  8811
# Winner is  p1
# GAME  8812
# Winner is  p1
# GAME  8813
# Winner is  p1
# GAME  8814
# Winner is  p1
# GAME  8815
# Winner is  p1
# GAME  8816
# Winner is  p1
# GAME  8817
# Winner is  p1
# GAME  8818
# Winner is  p1
# GAME  8819
# Winner is  p1
# GAME  8820
# Winner is  p1
# GAME  8821
# Winner is  p1
# GAME  8822
# Winner is  p1
# GAME  8823
# Winner is  p1
# GAME  8824
# Winner is  p1
# GAME  8825
# Winner is  p1
# GAME  8826
# Winner is  p1
# GAME  8827
# Winner is  p1
# GAME  8828
# Winner is  p1
# GAME  8829
# Winner is  p1
# GAME  8830
# Winner is  p1
# GAME  8831
# Winner is  p1
# GAME  8832
# Winner is  p1
# GAME  8833
# Winner is  p1
# GAME  8834
# Winner is  p1
# GAME  8835
# Winner is  p1
# GAME  8836
# Winner is  p1
# GAME  8837
# Winner is  p1
# GAME  8838
# Winner is  p1
# GAME  8839
# Winner is  p1
# GAME  8840
# Winner is  p1
# GAME  8841
# Winner is  p1
# GAME  8842
# Winner is  p1
# GAME  8843
# Winner is  p1
# GAME  8844
# Winner is  p1
# GAME  8845
# Winner is  p1
# GAME  8846
# Winner is  p1
# GAME  8847
# Winner is  p1
# GAME  8848
# Winner is  p1
# GAME  8849
# Winner is  p1
# GAME  8850
# Winner is  p1
# GAME  8851
# Winner is  p1
# GAME  8852
# Winner is  p1
# GAME  8853
# Winner is  p1
# GAME  8854
# Winner is  p1
# GAME  8855
# Winner is  p1
# GAME  8856
# Winner is  p1
# GAME  8857
# Winner is  p1
# GAME  8858
# Winner is  p1
# GAME  8859
# Winner is  p1
# GAME  8860
# Winner is  p1
# GAME  8861
# Winner is  p1
# GAME  8862
# Winner is  p1
# GAME  8863
# Winner is  p1
# GAME  8864
# Winner is  p1
# GAME  8865
# Winner is  p1
# GAME  8866
# Winner is  p1
# GAME  8867
# Winner is  p1
# GAME  8868
# Winner is  p1
# GAME  8869
# Winner is  p1
# GAME  8870
# Winner is  p1
# GAME  8871
# Winner is  p1
# GAME  8872
# Winner is  p1
# GAME  8873
# Winner is  p1
# GAME  8874
# Winner is  p1
# GAME  8875
# Winner is  p1
# GAME  8876
# Winner is  p1
# GAME  8877
# Winner is  p1
# GAME  8878
# Winner is  p1
# GAME  8879
# Winner is  p1
# GAME  8880
# Winner is  p1
# GAME  8881
# Winner is  p1
# GAME  8882
# Winner is  p1
# GAME  8883
# Winner is  p1
# GAME  8884
# Winner is  p1
# GAME  8885
# Winner is  p1
# GAME  8886
# Winner is  p1
# GAME  8887
# Winner is  p1
# GAME  8888
# Winner is  p1
# GAME  8889
# Winner is  p1
# GAME  8890
# Winner is  p1
# GAME  8891
# Winner is  p1
# GAME  8892
# Winner is  p1
# GAME  8893
# Winner is  p1
# GAME  8894
# Winner is  p1
# GAME  8895
# Winner is  p1
# GAME  8896
# Winner is  p1
# GAME  8897
# Winner is  p1
# GAME  8898
# Winner is  p1
# GAME  8899
# Winner is  p1
# GAME  8900
# Winner is  p1
# GAME  8901
# Winner is  p1
# GAME  8902
# Winner is  p1
# GAME  8903
# Winner is  p1
# GAME  8904
# Winner is  p1
# GAME  8905
# Winner is  p1
# GAME  8906
# Winner is  p1
# GAME  8907
# Winner is  p1
# GAME  8908
# Winner is  p1
# GAME  8909
# Winner is  p1
# GAME  8910
# Winner is  p1
# GAME  8911
# Winner is  p1
# GAME  8912
# Winner is  p1
# GAME  8913
# Winner is  p1
# GAME  8914
# Winner is  p1
# GAME  8915
# Winner is  p1
# GAME  8916
# Winner is  p1
# GAME  8917
# Winner is  p1
# GAME  8918
# Winner is  p1
# GAME  8919
# Winner is  p1
# GAME  8920
# Winner is  p1
# GAME  8921
# Winner is  p1
# GAME  8922
# Winner is  p1
# GAME  8923
# Winner is  p1
# GAME  8924
# Winner is  p1
# GAME  8925
# Winner is  p1
# GAME  8926
# Winner is  p1
# GAME  8927
# Winner is  p1
# GAME  8928
# Winner is  p1
# GAME  8929
# Winner is  p1
# GAME  8930
# Winner is  p1
# GAME  8931
# Winner is  p1
# GAME  8932
# Winner is  p1
# GAME  8933
# Winner is  p1
# GAME  8934
# Winner is  p1
# GAME  8935
# Winner is  p1
# GAME  8936
# Winner is  p1
# GAME  8937
# Winner is  p1
# GAME  8938
# Winner is  p1
# GAME  8939
# Winner is  p1
# GAME  8940
# Winner is  p1
# GAME  8941
# Winner is  p1
# GAME  8942
# Winner is  p1
# GAME  8943
# Winner is  p1
# GAME  8944
# Winner is  p1
# GAME  8945
# Winner is  p1
# GAME  8946
# Winner is  p1
# GAME  8947
# Winner is  p1
# GAME  8948
# Winner is  p1
# GAME  8949
# Winner is  p1
# GAME  8950
# Winner is  p1
# GAME  8951
# Winner is  p1
# GAME  8952
# Winner is  p1
# GAME  8953
# Winner is  p1
# GAME  8954
# Winner is  p1
# GAME  8955
# Winner is  p1
# GAME  8956
# Winner is  p1
# GAME  8957
# Winner is  p1
# GAME  8958
# Winner is  p1
# GAME  8959
# Winner is  p1
# GAME  8960
# Winner is  p1
# GAME  8961
# Winner is  p1
# GAME  8962
# Winner is  p1
# GAME  8963
# Winner is  p1
# GAME  8964
# Winner is  p1
# GAME  8965
# Winner is  p1
# GAME  8966
# Winner is  p1
# GAME  8967
# Winner is  p1
# GAME  8968
# Winner is  p1
# GAME  8969
# Winner is  p1
# GAME  8970
# Winner is  p1
# GAME  8971
# Winner is  p1
# GAME  8972
# Winner is  p1
# GAME  8973
# Winner is  p1
# GAME  8974
# Winner is  p1
# GAME  8975
# Winner is  p1
# GAME  8976
# Winner is  p1
# GAME  8977
# Winner is  p1
# GAME  8978
# Winner is  p1
# GAME  8979
# Winner is  p1
# GAME  8980
# Winner is  p1
# GAME  8981
# Winner is  p1
# GAME  8982
# Winner is  p1
# GAME  8983
# Winner is  p1
# GAME  8984
# Winner is  p1
# GAME  8985
# Winner is  p1
# GAME  8986
# Winner is  p1
# GAME  8987
# Winner is  p1
# GAME  8988
# Winner is  p1
# GAME  8989
# Winner is  p1
# GAME  8990
# Winner is  p1
# GAME  8991
# Winner is  p1
# GAME  8992
# Winner is  p1
# GAME  8993
# Winner is  p1
# GAME  8994
# Winner is  p1
# GAME  8995
# Winner is  p1
# GAME  8996
# Winner is  p1
# GAME  8997
# Winner is  p1
# GAME  8998
# Winner is  p1
# GAME  8999
# Winner is  p1
# GAME  9000
# Winner is  p1
# GAME  9001
# Winner is  p1
# GAME  9002
# Winner is  p1
# GAME  9003
# Winner is  p1
# GAME  9004
# Winner is  p1
# GAME  9005
# Winner is  p1
# GAME  9006
# Winner is  p1
# GAME  9007
# Winner is  p1
# GAME  9008
# Winner is  p1
# GAME  9009
# Winner is  p1
# GAME  9010
# Winner is  p1
# GAME  9011
# Winner is  p1
# GAME  9012
# Winner is  p1
# GAME  9013
# Winner is  p1
# GAME  9014
# Winner is  p1
# GAME  9015
# Winner is  p1
# GAME  9016
# Winner is  p1
# GAME  9017
# Winner is  p1
# GAME  9018
# Winner is  p1
# GAME  9019
# Winner is  p1
# GAME  9020
# Winner is  p1
# GAME  9021
# Winner is  p1
# GAME  9022
# Winner is  p1
# GAME  9023
# Winner is  p1
# GAME  9024
# Winner is  p1
# GAME  9025
# Winner is  p1
# GAME  9026
# Winner is  p1
# GAME  9027
# Winner is  p1
# GAME  9028
# Winner is  p1
# GAME  9029
# Winner is  p1
# GAME  9030
# Winner is  p1
# GAME  9031
# Winner is  p1
# GAME  9032
# Winner is  p1
# GAME  9033
# Winner is  p1
# GAME  9034
# Winner is  p1
# GAME  9035
# Winner is  p1
# GAME  9036
# Winner is  p1
# GAME  9037
# Winner is  p1
# GAME  9038
# Winner is  p1
# GAME  9039
# Winner is  p1
# GAME  9040
# Winner is  p1
# GAME  9041
# Winner is  p1
# GAME  9042
# Winner is  p1
# GAME  9043
# Winner is  p1
# GAME  9044
# Winner is  p1
# GAME  9045
# Winner is  p1
# GAME  9046
# Winner is  p1
# GAME  9047
# Winner is  p1
# GAME  9048
# Winner is  p1
# GAME  9049
# Winner is  p1
# GAME  9050
# Winner is  p1
# GAME  9051
# Winner is  p1
# GAME  9052
# Winner is  p1
# GAME  9053
# Winner is  p1
# GAME  9054
# Winner is  p1
# GAME  9055
# Winner is  p1
# GAME  9056
# Winner is  p1
# GAME  9057
# Winner is  p1
# GAME  9058
# Winner is  p1
# GAME  9059
# Winner is  p1
# GAME  9060
# Winner is  p1
# GAME  9061
# Winner is  p1
# GAME  9062
# Winner is  p1
# GAME  9063
# Winner is  p1
# GAME  9064
# Winner is  p1
# GAME  9065
# Winner is  p1
# GAME  9066
# Winner is  p1
# GAME  9067
# Winner is  p1
# GAME  9068
# Winner is  p1
# GAME  9069
# Winner is  p1
# GAME  9070
# Winner is  p1
# GAME  9071
# Winner is  p1
# GAME  9072
# Winner is  p1
# GAME  9073
# Winner is  p1
# GAME  9074
# Winner is  p1
# GAME  9075
# Winner is  p1
# GAME  9076
# Winner is  p1
# GAME  9077
# Winner is  p1
# GAME  9078
# Winner is  p1
# GAME  9079
# Winner is  p1
# GAME  9080
# Winner is  p1
# GAME  9081
# Winner is  p1
# GAME  9082
# Winner is  p1
# GAME  9083
# Winner is  p1
# GAME  9084
# Winner is  p1
# GAME  9085
# Winner is  p1
# GAME  9086
# Winner is  p1
# GAME  9087
# Winner is  p1
# GAME  9088
# Winner is  p1
# GAME  9089
# Winner is  p1
# GAME  9090
# Winner is  p1
# GAME  9091
# Winner is  p1
# GAME  9092
# Winner is  p1
# GAME  9093
# Winner is  p1
# GAME  9094
# Winner is  p1
# GAME  9095
# Winner is  p1
# GAME  9096
# Winner is  p1
# GAME  9097
# Winner is  p1
# GAME  9098
# Winner is  p1
# GAME  9099
# Winner is  p1
# GAME  9100
# Winner is  p1
# GAME  9101
# Winner is  p1
# GAME  9102
# Winner is  p1
# GAME  9103
# Winner is  p1
# GAME  9104
# Winner is  p1
# GAME  9105
# Winner is  p1
# GAME  9106
# Winner is  p1
# GAME  9107
# Winner is  p1
# GAME  9108
# Winner is  p1
# GAME  9109
# Winner is  p1
# GAME  9110
# Winner is  p1
# GAME  9111
# Winner is  p1
# GAME  9112
# Winner is  p1
# GAME  9113
# Winner is  p1
# GAME  9114
# Winner is  p1
# GAME  9115
# Winner is  p1
# GAME  9116
# Winner is  p1
# GAME  9117
# Winner is  p1
# GAME  9118
# Winner is  p1
# GAME  9119
# Winner is  p1
# GAME  9120
# Winner is  p1
# GAME  9121
# Winner is  p1
# GAME  9122
# Winner is  p1
# GAME  9123
# Winner is  p1
# GAME  9124
# Winner is  p1
# GAME  9125
# Winner is  p1
# GAME  9126
# Winner is  p1
# GAME  9127
# Winner is  p1
# GAME  9128
# Winner is  p1
# GAME  9129
# Winner is  p1
# GAME  9130
# Winner is  p1
# GAME  9131
# Winner is  p1
# GAME  9132
# Winner is  p1
# GAME  9133
# Winner is  p1
# GAME  9134
# Winner is  p1
# GAME  9135
# Winner is  p1
# GAME  9136
# Winner is  p1
# GAME  9137
# Winner is  p1
# GAME  9138
# Winner is  p1
# GAME  9139
# Winner is  p1
# GAME  9140
# Winner is  p1
# GAME  9141
# Winner is  p1
# GAME  9142
# Winner is  p1
# GAME  9143
# Winner is  p1
# GAME  9144
# Winner is  p1
# GAME  9145
# Winner is  p1
# GAME  9146
# Winner is  p1
# GAME  9147
# Winner is  p1
# GAME  9148
# Winner is  p1
# GAME  9149
# Winner is  p1
# GAME  9150
# Winner is  p1
# GAME  9151
# Winner is  p1
# GAME  9152
# Winner is  p1
# GAME  9153
# Winner is  p1
# GAME  9154
# Winner is  p1
# GAME  9155
# Winner is  p1
# GAME  9156
# Winner is  p1
# GAME  9157
# Winner is  p1
# GAME  9158
# Winner is  p1
# GAME  9159
# Winner is  p1
# GAME  9160
# Winner is  p1
# GAME  9161
# Winner is  p1
# GAME  9162
# Winner is  p1
# GAME  9163
# Winner is  p1
# GAME  9164
# Winner is  p1
# GAME  9165
# Winner is  p1
# GAME  9166
# Winner is  p1
# GAME  9167
# Winner is  p1
# GAME  9168
# Winner is  p1
# GAME  9169
# Winner is  p1
# GAME  9170
# Winner is  p1
# GAME  9171
# Winner is  p1
# GAME  9172
# Winner is  p1
# GAME  9173
# Winner is  p1
# GAME  9174
# Winner is  p1
# GAME  9175
# Winner is  p1
# GAME  9176
# Winner is  p1
# GAME  9177
# Winner is  p1
# GAME  9178
# Winner is  p1
# GAME  9179
# Winner is  p1
# GAME  9180
# Winner is  p1
# GAME  9181
# Winner is  p1
# GAME  9182
# Winner is  p1
# GAME  9183
# Winner is  p1
# GAME  9184
# Winner is  p1
# GAME  9185
# Winner is  p1
# GAME  9186
# Winner is  p1
# GAME  9187
# Winner is  p1
# GAME  9188
# Winner is  p1
# GAME  9189
# Winner is  p1
# GAME  9190
# Winner is  p1
# GAME  9191
# Winner is  p1
# GAME  9192
# Winner is  p1
# GAME  9193
# Winner is  p1
# GAME  9194
# Winner is  p1
# GAME  9195
# Winner is  p1
# GAME  9196
# Winner is  p1
# GAME  9197
# Winner is  p1
# GAME  9198
# Winner is  p1
# GAME  9199
# Winner is  p1
# GAME  9200
# Winner is  p1
# GAME  9201
# Winner is  p1
# GAME  9202
# Winner is  p1
# GAME  9203
# Winner is  p1
# GAME  9204
# Winner is  p1
# GAME  9205
# Winner is  p1
# GAME  9206
# Winner is  p1
# GAME  9207
# Winner is  p1
# GAME  9208
# Winner is  p1
# GAME  9209
# Winner is  p1
# GAME  9210
# Winner is  p1
# GAME  9211
# Winner is  p1
# GAME  9212
# Winner is  p1
# GAME  9213
# Winner is  p1
# GAME  9214
# Winner is  p1
# GAME  9215
# Winner is  p1
# GAME  9216
# Winner is  p1
# GAME  9217
# Winner is  p1
# GAME  9218
# Winner is  p1
# GAME  9219
# Winner is  p1
# GAME  9220
# Winner is  p1
# GAME  9221
# Winner is  p1
# GAME  9222
# Winner is  p1
# GAME  9223
# Winner is  p1
# GAME  9224
# Winner is  p1
# GAME  9225
# Winner is  p1
# GAME  9226
# Winner is  p1
# GAME  9227
# Winner is  p1
# GAME  9228
# Winner is  p1
# GAME  9229
# Winner is  p1
# GAME  9230
# Winner is  p1
# GAME  9231
# Winner is  p1
# GAME  9232
# Winner is  p1
# GAME  9233
# Winner is  p1
# GAME  9234
# Winner is  p1
# GAME  9235
# Winner is  p1
# GAME  9236
# Winner is  p1
# GAME  9237
# Winner is  p1
# GAME  9238
# Winner is  p1
# GAME  9239
# Winner is  p1
# GAME  9240
# Winner is  p1
# GAME  9241
# Winner is  p1
# GAME  9242
# Winner is  p1
# GAME  9243
# Winner is  p1
# GAME  9244
# Winner is  p1
# GAME  9245
# Winner is  p1
# GAME  9246
# Winner is  p1
# GAME  9247
# Winner is  p1
# GAME  9248
# Winner is  p1
# GAME  9249
# Winner is  p1
# GAME  9250
# Winner is  p1
# GAME  9251
# Winner is  p1
# GAME  9252
# Winner is  p1
# GAME  9253
# Winner is  p1
# GAME  9254
# Winner is  p1
# GAME  9255
# Winner is  p1
# GAME  9256
# Winner is  p1
# GAME  9257
# Winner is  p1
# GAME  9258
# Winner is  p1
# GAME  9259
# Winner is  p1
# GAME  9260
# Winner is  p1
# GAME  9261
# Winner is  p1
# GAME  9262
# Winner is  p1
# GAME  9263
# Winner is  p1
# GAME  9264
# Winner is  p1
# GAME  9265
# Winner is  p1
# GAME  9266
# Winner is  p1
# GAME  9267
# Winner is  p1
# GAME  9268
# Winner is  p1
# GAME  9269
# Winner is  p1
# GAME  9270
# Winner is  p1
# GAME  9271
# Winner is  p1
# GAME  9272
# Winner is  p1
# GAME  9273
# Winner is  p1
# GAME  9274
# Winner is  p1
# GAME  9275
# Winner is  p1
# GAME  9276
# Winner is  p1
# GAME  9277
# Winner is  p1
# GAME  9278
# Winner is  p1
# GAME  9279
# Winner is  p1
# GAME  9280
# Winner is  p1
# GAME  9281
# Winner is  p1
# GAME  9282
# Winner is  p1
# GAME  9283
# Winner is  p1
# GAME  9284
# Winner is  p1
# GAME  9285
# Winner is  p1
# GAME  9286
# Winner is  p1
# GAME  9287
# Winner is  p1
# GAME  9288
# Winner is  p1
# GAME  9289
# Winner is  p1
# GAME  9290
# Winner is  p1
# GAME  9291
# Winner is  p1
# GAME  9292
# Winner is  p1
# GAME  9293
# Winner is  p1
# GAME  9294
# Winner is  p1
# GAME  9295
# Winner is  p1
# GAME  9296
# Winner is  p1
# GAME  9297
# Winner is  p1
# GAME  9298
# Winner is  p1
# GAME  9299
# Winner is  p1
# GAME  9300
# Winner is  p1
# GAME  9301
# Winner is  p1
# GAME  9302
# Winner is  p1
# GAME  9303
# Winner is  p1
# GAME  9304
# Winner is  p1
# GAME  9305
# Winner is  p1
# GAME  9306
# Winner is  p1
# GAME  9307
# Winner is  p1
# GAME  9308
# Winner is  p1
# GAME  9309
# Winner is  p1
# GAME  9310
# Winner is  p1
# GAME  9311
# Winner is  p1
# GAME  9312
# Winner is  p1
# GAME  9313
# Winner is  p1
# GAME  9314
# Winner is  p1
# GAME  9315
# Winner is  p1
# GAME  9316
# Winner is  p1
# GAME  9317
# Winner is  p1
# GAME  9318
# Winner is  p1
# GAME  9319
# Winner is  p1
# GAME  9320
# Winner is  p1
# GAME  9321
# Winner is  p1
# GAME  9322
# Winner is  p1
# GAME  9323
# Winner is  p1
# GAME  9324
# Winner is  p1
# GAME  9325
# Winner is  p1
# GAME  9326
# Winner is  p1
# GAME  9327
# Winner is  p1
# GAME  9328
# Winner is  p1
# GAME  9329
# Winner is  p1
# GAME  9330
# Winner is  p1
# GAME  9331
# Winner is  p1
# GAME  9332
# Winner is  p1
# GAME  9333
# Winner is  p1
# GAME  9334
# Winner is  p1
# GAME  9335
# Winner is  p1
# GAME  9336
# Winner is  p1
# GAME  9337
# Winner is  p1
# GAME  9338
# Winner is  p1
# GAME  9339
# Winner is  p1
# GAME  9340
# Winner is  p1
# GAME  9341
# Winner is  p1
# GAME  9342
# Winner is  p1
# GAME  9343
# Winner is  p1
# GAME  9344
# Winner is  p1
# GAME  9345
# Winner is  p1
# GAME  9346
# Winner is  p1
# GAME  9347
# Winner is  p1
# GAME  9348
# Winner is  p1
# GAME  9349
# Winner is  p1
# GAME  9350
# Winner is  p1
# GAME  9351
# Winner is  p1
# GAME  9352
# Winner is  p1
# GAME  9353
# Winner is  p1
# GAME  9354
# Winner is  p1
# GAME  9355
# Winner is  p1
# GAME  9356
# Winner is  p1
# GAME  9357
# Winner is  p1
# GAME  9358
# Winner is  p1
# GAME  9359
# Winner is  p1
# GAME  9360
# Winner is  p1
# GAME  9361
# Winner is  p1
# GAME  9362
# Winner is  p1
# GAME  9363
# Winner is  p1
# GAME  9364
# Winner is  p1
# GAME  9365
# Winner is  p1
# GAME  9366
# Winner is  p1
# GAME  9367
# Winner is  p1
# GAME  9368
# Winner is  p1
# GAME  9369
# Winner is  p1
# GAME  9370
# Winner is  p1
# GAME  9371
# Winner is  p1
# GAME  9372
# Winner is  p1
# GAME  9373
# Winner is  p1
# GAME  9374
# Winner is  p1
# GAME  9375
# Winner is  p1
# GAME  9376
# Winner is  p1
# GAME  9377
# Winner is  p1
# GAME  9378
# Winner is  p1
# GAME  9379
# Winner is  p1
# GAME  9380
# Winner is  p1
# GAME  9381
# Winner is  p1
# GAME  9382
# Winner is  p1
# GAME  9383
# Winner is  p1
# GAME  9384
# Winner is  p1
# GAME  9385
# Winner is  p1
# GAME  9386
# Winner is  p1
# GAME  9387
# Winner is  p1
# GAME  9388
# Winner is  p1
# GAME  9389
# Winner is  p1
# GAME  9390
# Winner is  p1
# GAME  9391
# Winner is  p1
# GAME  9392
# Winner is  p1
# GAME  9393
# Winner is  p1
# GAME  9394
# Winner is  p1
# GAME  9395
# Winner is  p1
# GAME  9396
# Winner is  p1
# GAME  9397
# Winner is  p1
# GAME  9398
# Winner is  p1
# GAME  9399
# Winner is  p1
# GAME  9400
# Winner is  p1
# GAME  9401
# Winner is  p1
# GAME  9402
# Winner is  p1
# GAME  9403
# Winner is  p1
# GAME  9404
# Winner is  p1
# GAME  9405
# Winner is  p1
# GAME  9406
# Winner is  p1
# GAME  9407
# Winner is  p1
# GAME  9408
# Winner is  p1
# GAME  9409
# Winner is  p1
# GAME  9410
# Winner is  p1
# GAME  9411
# Winner is  p1
# GAME  9412
# Winner is  p1
# GAME  9413
# Winner is  p1
# GAME  9414
# Winner is  p1
# GAME  9415
# Winner is  p1
# GAME  9416
# Winner is  p1
# GAME  9417
# Winner is  p1
# GAME  9418
# Winner is  p1
# GAME  9419
# Winner is  p1
# GAME  9420
# Winner is  p1
# GAME  9421
# Winner is  p1
# GAME  9422
# Winner is  p1
# GAME  9423
# Winner is  p1
# GAME  9424
# Winner is  p1
# GAME  9425
# Winner is  p1
# GAME  9426
# Winner is  p1
# GAME  9427
# Winner is  p1
# GAME  9428
# Winner is  p1
# GAME  9429
# Winner is  p1
# GAME  9430
# Winner is  p1
# GAME  9431
# Winner is  p1
# GAME  9432
# Winner is  p1
# GAME  9433
# Winner is  p1
# GAME  9434
# Winner is  p1
# GAME  9435
# Winner is  p1
# GAME  9436
# Winner is  p1
# GAME  9437
# Winner is  p1
# GAME  9438
# Winner is  p1
# GAME  9439
# Winner is  p1
# GAME  9440
# Winner is  p1
# GAME  9441
# Winner is  p1
# GAME  9442
# Winner is  p1
# GAME  9443
# Winner is  p1
# GAME  9444
# Winner is  p1
# GAME  9445
# Winner is  p1
# GAME  9446
# Winner is  p1
# GAME  9447
# Winner is  p1
# GAME  9448
# Winner is  p1
# GAME  9449
# Winner is  p1
# GAME  9450
# Winner is  p1
# GAME  9451
# Winner is  p1
# GAME  9452
# Winner is  p1
# GAME  9453
# Winner is  p1
# GAME  9454
# Winner is  p1
# GAME  9455
# Winner is  p1
# GAME  9456
# Winner is  p1
# GAME  9457
# Winner is  p1
# GAME  9458
# Winner is  p1
# GAME  9459
# Winner is  p1
# GAME  9460
# Winner is  p1
# GAME  9461
# Winner is  p1
# GAME  9462
# Winner is  p1
# GAME  9463
# Winner is  p1
# GAME  9464
# Winner is  p1
# GAME  9465
# Winner is  p1
# GAME  9466
# Winner is  p1
# GAME  9467
# Winner is  p1
# GAME  9468
# Winner is  p1
# GAME  9469
# Winner is  p1
# GAME  9470
# Winner is  p1
# GAME  9471
# Winner is  p1
# GAME  9472
# Winner is  p1
# GAME  9473
# Winner is  p1
# GAME  9474
# Winner is  p1
# GAME  9475
# Winner is  p1
# GAME  9476
# Winner is  p1
# GAME  9477
# Winner is  p1
# GAME  9478
# Winner is  p1
# GAME  9479
# Winner is  p1
# GAME  9480
# Winner is  p1
# GAME  9481
# Winner is  p1
# GAME  9482
# Winner is  p1
# GAME  9483
# Winner is  p1
# GAME  9484
# Winner is  p1
# GAME  9485
# Winner is  p1
# GAME  9486
# Winner is  p1
# GAME  9487
# Winner is  p1
# GAME  9488
# Winner is  p1
# GAME  9489
# Winner is  p1
# GAME  9490
# Winner is  p1
# GAME  9491
# Winner is  p1
# GAME  9492
# Winner is  p1
# GAME  9493
# Winner is  p1
# GAME  9494
# Winner is  p1
# GAME  9495
# Winner is  p1
# GAME  9496
# Winner is  p1
# GAME  9497
# Winner is  p1
# GAME  9498
# Winner is  p1
# GAME  9499
# Winner is  p1
# GAME  9500
# Winner is  p1
# GAME  9501
# Winner is  p1
# GAME  9502
# Winner is  p1
# GAME  9503
# Winner is  p1
# GAME  9504
# Winner is  p1
# GAME  9505
# Winner is  p1
# GAME  9506
# Winner is  p1
# GAME  9507
# Winner is  p1
# GAME  9508
# Winner is  p1
# GAME  9509
# Winner is  p1
# GAME  9510
# Winner is  p1
# GAME  9511
# Winner is  p1
# GAME  9512
# Winner is  p1
# GAME  9513
# Winner is  p1
# GAME  9514
# Winner is  p1
# GAME  9515
# Winner is  p1
# GAME  9516
# Winner is  p1
# GAME  9517
# Winner is  p1
# GAME  9518
# Winner is  p1
# GAME  9519
# Winner is  p1
# GAME  9520
# Winner is  p1
# GAME  9521
# Winner is  p1
# GAME  9522
# Winner is  p1
# GAME  9523
# Winner is  p1
# GAME  9524
# Winner is  p1
# GAME  9525
# Winner is  p1
# GAME  9526
# Winner is  p1
# GAME  9527
# Winner is  p1
# GAME  9528
# Winner is  p1
# GAME  9529
# Winner is  p1
# GAME  9530
# Winner is  p1
# GAME  9531
# Winner is  p1
# GAME  9532
# Winner is  p1
# GAME  9533
# Winner is  p1
# GAME  9534
# Winner is  p1
# GAME  9535
# Winner is  p1
# GAME  9536
# Winner is  p1
# GAME  9537
# Winner is  p1
# GAME  9538
# Winner is  p1
# GAME  9539
# Winner is  p1
# GAME  9540
# Winner is  p1
# GAME  9541
# Winner is  p1
# GAME  9542
# Winner is  p1
# GAME  9543
# Winner is  p1
# GAME  9544
# Winner is  p1
# GAME  9545
# Winner is  p1
# GAME  9546
# Winner is  p1
# GAME  9547
# Winner is  p1
# GAME  9548
# Winner is  p1
# GAME  9549
# Winner is  p1
# GAME  9550
# Winner is  p1
# GAME  9551
# Winner is  p1
# GAME  9552
# Winner is  p1
# GAME  9553
# Winner is  p1
# GAME  9554
# Winner is  p1
# GAME  9555
# Winner is  p1
# GAME  9556
# Winner is  p1
# GAME  9557
# Winner is  p1
# GAME  9558
# Winner is  p1
# GAME  9559
# Winner is  p1
# GAME  9560
# Winner is  p1
# GAME  9561
# Winner is  p1
# GAME  9562
# Winner is  p1
# GAME  9563
# Winner is  p1
# GAME  9564
# Winner is  p1
# GAME  9565
# Winner is  p1
# GAME  9566
# Winner is  p1
# GAME  9567
# Winner is  p1
# GAME  9568
# Winner is  p1
# GAME  9569
# Winner is  p1
# GAME  9570
# Winner is  p1
# GAME  9571
# Winner is  p1
# GAME  9572
# Winner is  p1
# GAME  9573
# Winner is  p1
# GAME  9574
# Winner is  p1
# GAME  9575
# Winner is  p1
# GAME  9576
# Winner is  p1
# GAME  9577
# Winner is  p1
# GAME  9578
# Winner is  p1
# GAME  9579
# Winner is  p1
# GAME  9580
# Winner is  p1
# GAME  9581
# Winner is  p1
# GAME  9582
# Winner is  p1
# GAME  9583
# Winner is  p1
# GAME  9584
# Winner is  p1
# GAME  9585
# Winner is  p1
# GAME  9586
# Winner is  p1
# GAME  9587
# Winner is  p1
# GAME  9588
# Winner is  p1
# GAME  9589
# Winner is  p1
# GAME  9590
# Winner is  p1
# GAME  9591
# Winner is  p1
# GAME  9592
# Winner is  p1
# GAME  9593
# Winner is  p1
# GAME  9594
# Winner is  p1
# GAME  9595
# Winner is  p1
# GAME  9596
# Winner is  p1
# GAME  9597
# Winner is  p1
# GAME  9598
# Winner is  p1
# GAME  9599
# Winner is  p1
# GAME  9600
# Winner is  p1
# GAME  9601
# Winner is  p1
# GAME  9602
# Winner is  p1
# GAME  9603
# Winner is  p1
# GAME  9604
# Winner is  p1
# GAME  9605
# Winner is  p1
# GAME  9606
# Winner is  p1
# GAME  9607
# Winner is  p1
# GAME  9608
# Winner is  p1
# GAME  9609
# Winner is  p1
# GAME  9610
# Winner is  p1
# GAME  9611
# Winner is  p1
# GAME  9612
# Winner is  p1
# GAME  9613
# Winner is  p1
# GAME  9614
# Winner is  p1
# GAME  9615
# Winner is  p1
# GAME  9616
# Winner is  p1
# GAME  9617
# Winner is  p1
# GAME  9618
# Winner is  p1
# GAME  9619
# Winner is  p1
# GAME  9620
# Winner is  p1
# GAME  9621
# Winner is  p1
# GAME  9622
# Winner is  p1
# GAME  9623
# Winner is  p1
# GAME  9624
# Winner is  p1
# GAME  9625
# Winner is  p1
# GAME  9626
# Winner is  p1
# GAME  9627
# Winner is  p1
# GAME  9628
# Winner is  p1
# GAME  9629
# Winner is  p1
# GAME  9630
# Winner is  p1
# GAME  9631
# Winner is  p1
# GAME  9632
# Winner is  p1
# GAME  9633
# Winner is  p1
# GAME  9634
# Winner is  p1
# GAME  9635
# Winner is  p1
# GAME  9636
# Winner is  p1
# GAME  9637
# Winner is  p1
# GAME  9638
# Winner is  p1
# GAME  9639
# Winner is  p1
# GAME  9640
# Winner is  p1
# GAME  9641
# Winner is  p1
# GAME  9642
# Winner is  p1
# GAME  9643
# Winner is  p1
# GAME  9644
# Winner is  p1
# GAME  9645
# Winner is  p1
# GAME  9646
# Winner is  p1
# GAME  9647
# Winner is  p1
# GAME  9648
# Winner is  p1
# GAME  9649
# Winner is  p1
# GAME  9650
# Winner is  p1
# GAME  9651
# Winner is  p1
# GAME  9652
# Winner is  p1
# GAME  9653
# Winner is  p1
# GAME  9654
# Winner is  p1
# GAME  9655
# Winner is  p1
# GAME  9656
# Winner is  p1
# GAME  9657
# Winner is  p1
# GAME  9658
# Winner is  p1
# GAME  9659
# Winner is  p1
# GAME  9660
# Winner is  p1
# GAME  9661
# Winner is  p1
# GAME  9662
# Winner is  p1
# GAME  9663
# Winner is  p1
# GAME  9664
# Winner is  p1
# GAME  9665
# Winner is  p1
# GAME  9666
# Winner is  p1
# GAME  9667
# Winner is  p1
# GAME  9668
# Winner is  p1
# GAME  9669
# Winner is  p1
# GAME  9670
# Winner is  p1
# GAME  9671
# Winner is  p1
# GAME  9672
# Winner is  p1
# GAME  9673
# Winner is  p1
# GAME  9674
# Winner is  p1
# GAME  9675
# Winner is  p1
# GAME  9676
# Winner is  p1
# GAME  9677
# Winner is  p1
# GAME  9678
# Winner is  p1
# GAME  9679
# Winner is  p1
# GAME  9680
# Winner is  p1
# GAME  9681
# Winner is  p1
# GAME  9682
# Winner is  p1
# GAME  9683
# Winner is  p1
# GAME  9684
# Winner is  p1
# GAME  9685
# Winner is  p1
# GAME  9686
# Winner is  p1
# GAME  9687
# Winner is  p1
# GAME  9688
# Winner is  p1
# GAME  9689
# Winner is  p1
# GAME  9690
# Winner is  p1
# GAME  9691
# Winner is  p1
# GAME  9692
# Winner is  p1
# GAME  9693
# Winner is  p1
# GAME  9694
# Winner is  p1
# GAME  9695
# Winner is  p1
# GAME  9696
# Winner is  p1
# GAME  9697
# Winner is  p1
# GAME  9698
# Winner is  p1
# GAME  9699
# Winner is  p1
# GAME  9700
# Winner is  p1
# GAME  9701
# Winner is  p1
# GAME  9702
# Winner is  p1
# GAME  9703
# Winner is  p1
# GAME  9704
# Winner is  p1
# GAME  9705
# Winner is  p1
# GAME  9706
# Winner is  p1
# GAME  9707
# Winner is  p1
# GAME  9708
# Winner is  p1
# GAME  9709
# Winner is  p1
# GAME  9710
# Winner is  p1
# GAME  9711
# Winner is  p1
# GAME  9712
# Winner is  p1
# GAME  9713
# Winner is  p1
# GAME  9714
# Winner is  p1
# GAME  9715
# Winner is  p1
# GAME  9716
# Winner is  p1
# GAME  9717
# Winner is  p1
# GAME  9718
# Winner is  p1
# GAME  9719
# Winner is  p1
# GAME  9720
# Winner is  p1
# GAME  9721
# Winner is  p1
# GAME  9722
# Winner is  p1
# GAME  9723
# Winner is  p1
# GAME  9724
# Winner is  p1
# GAME  9725
# Winner is  p1
# GAME  9726
# Winner is  p1
# GAME  9727
# Winner is  p1
# GAME  9728
# Winner is  p1
# GAME  9729
# Winner is  p1
# GAME  9730
# Winner is  p1
# GAME  9731
# Winner is  p1
# GAME  9732
# Winner is  p1
# GAME  9733
# Winner is  p1
# GAME  9734
# Winner is  p1
# GAME  9735
# Winner is  p1
# GAME  9736
# Winner is  p1
# GAME  9737
# Winner is  p1
# GAME  9738
# Winner is  p1
# GAME  9739
# Winner is  p1
# GAME  9740
# Winner is  p1
# GAME  9741
# Winner is  p1
# GAME  9742
# Winner is  p1
# GAME  9743
# Winner is  p1
# GAME  9744
# Winner is  p1
# GAME  9745
# Winner is  p1
# GAME  9746
# Winner is  p1
# GAME  9747
# Winner is  p1
# GAME  9748
# Winner is  p1
# GAME  9749
# Winner is  p1
# GAME  9750
# Winner is  p1
# GAME  9751
# Winner is  p1
# GAME  9752
# Winner is  p1
# GAME  9753
# Winner is  p1
# GAME  9754
# Winner is  p1
# GAME  9755
# Winner is  p1
# GAME  9756
# Winner is  p1
# GAME  9757
# Winner is  p1
# GAME  9758
# Winner is  p1
# GAME  9759
# Winner is  p1
# GAME  9760
# Winner is  p1
# GAME  9761
# Winner is  p1
# GAME  9762
# Winner is  p1
# GAME  9763
# Winner is  p1
# GAME  9764
# Winner is  p1
# GAME  9765
# Winner is  p1
# GAME  9766
# Winner is  p1
# GAME  9767
# Winner is  p1
# GAME  9768
# Winner is  p1
# GAME  9769
# Winner is  p1
# GAME  9770
# Winner is  p1
# GAME  9771
# Winner is  p1
# GAME  9772
# Winner is  p1
# GAME  9773
# Winner is  p1
# GAME  9774
# Winner is  p1
# GAME  9775
# Winner is  p1
# GAME  9776
# Winner is  p1
# GAME  9777
# Winner is  p1
# GAME  9778
# Winner is  p1
# GAME  9779
# Winner is  p1
# GAME  9780
# Winner is  p1
# GAME  9781
# Winner is  p1
# GAME  9782
# Winner is  p1
# GAME  9783
# Winner is  p1
# GAME  9784
# Winner is  p1
# GAME  9785
# Winner is  p1
# GAME  9786
# Winner is  p1
# GAME  9787
# Winner is  p1
# GAME  9788
# Winner is  p1
# GAME  9789
# Winner is  p1
# GAME  9790
# Winner is  p1
# GAME  9791
# Winner is  p1
# GAME  9792
# Winner is  p1
# GAME  9793
# Winner is  p1
# GAME  9794
# Winner is  p1
# GAME  9795
# Winner is  p1
# GAME  9796
# Winner is  p1
# GAME  9797
# Winner is  p1
# GAME  9798
# Winner is  p1
# GAME  9799
# Winner is  p1
# GAME  9800
# Winner is  p1
# GAME  9801
# Winner is  p1
# GAME  9802
# Winner is  p1
# GAME  9803
# Winner is  p1
# GAME  9804
# Winner is  p1
# GAME  9805
# Winner is  p1
# GAME  9806
# Winner is  p1
# GAME  9807
# Winner is  p1
# GAME  9808
# Winner is  p1
# GAME  9809
# Winner is  p1
# GAME  9810
# Winner is  p1
# GAME  9811
# Winner is  p1
# GAME  9812
# Winner is  p1
# GAME  9813
# Winner is  p1
# GAME  9814
# Winner is  p1
# GAME  9815
# Winner is  p1
# GAME  9816
# Winner is  p1
# GAME  9817
# Winner is  p1
# GAME  9818
# Winner is  p1
# GAME  9819
# Winner is  p1
# GAME  9820
# Winner is  p1
# GAME  9821
# Winner is  p1
# GAME  9822
# Winner is  p1
# GAME  9823
# Winner is  p1
# GAME  9824
# Winner is  p1
# GAME  9825
# Winner is  p1
# GAME  9826
# Winner is  p1
# GAME  9827
# Winner is  p1
# GAME  9828
# Winner is  p1
# GAME  9829
# Winner is  p1
# GAME  9830
# Winner is  p1
# GAME  9831
# Winner is  p1
# GAME  9832
# Winner is  p1
# GAME  9833
# Winner is  p1
# GAME  9834
# Winner is  p1
# GAME  9835
# Winner is  p1
# GAME  9836
# Winner is  p1
# GAME  9837
# Winner is  p1
# GAME  9838
# Winner is  p1
# GAME  9839
# Winner is  p1
# GAME  9840
# Winner is  p1
# GAME  9841
# Winner is  p1
# GAME  9842
# Winner is  p1
# GAME  9843
# Winner is  p1
# GAME  9844
# Winner is  p1
# GAME  9845
# Winner is  p1
# GAME  9846
# Winner is  p1
# GAME  9847
# Winner is  p1
# GAME  9848
# Winner is  p1
# GAME  9849
# Winner is  p1
# GAME  9850
# Winner is  p1
# GAME  9851
# Winner is  p1
# GAME  9852
# Winner is  p1
# GAME  9853
# Winner is  p1
# GAME  9854
# Winner is  p1
# GAME  9855
# Winner is  p1
# GAME  9856
# Winner is  p1
# GAME  9857
# Winner is  p1
# GAME  9858
# Winner is  p1
# GAME  9859
# Winner is  p1
# GAME  9860
# Winner is  p1
# GAME  9861
# Winner is  p1
# GAME  9862
# Winner is  p1
# GAME  9863
# Winner is  p1
# GAME  9864
# Winner is  p1
# GAME  9865
# Winner is  p1
# GAME  9866
# Winner is  p1
# GAME  9867
# Winner is  p1
# GAME  9868
# Winner is  p1
# GAME  9869
# Winner is  p1
# GAME  9870
# Winner is  p1
# GAME  9871
# Winner is  p1
# GAME  9872
# Winner is  p1
# GAME  9873
# Winner is  p1
# GAME  9874
# Winner is  p1
# GAME  9875
# Winner is  p1
# GAME  9876
# Winner is  p1
# GAME  9877
# Winner is  p1
# GAME  9878
# Winner is  p1
# GAME  9879
# Winner is  p1
# GAME  9880
# Winner is  p1
# GAME  9881
# Winner is  p1
# GAME  9882
# Winner is  p1
# GAME  9883
# Winner is  p1
# GAME  9884
# Winner is  p1
# GAME  9885
# Winner is  p1
# GAME  9886
# Winner is  p1
# GAME  9887
# Winner is  p1
# GAME  9888
# Winner is  p1
# GAME  9889
# Winner is  p1
# GAME  9890
# Winner is  p1
# GAME  9891
# Winner is  p1
# GAME  9892
# Winner is  p1
# GAME  9893
# Winner is  p1
# GAME  9894
# Winner is  p1
# GAME  9895
# Winner is  p1
# GAME  9896
# Winner is  p1
# GAME  9897
# Winner is  p1
# GAME  9898
# Winner is  p1
# GAME  9899
# Winner is  p1
# GAME  9900
# Winner is  p1
# GAME  9901
# Winner is  p1
# GAME  9902
# Winner is  p1
# GAME  9903
# Winner is  p1
# GAME  9904
# Winner is  p1
# GAME  9905
# Winner is  p1
# GAME  9906
# Winner is  p1
# GAME  9907
# Winner is  p1
# GAME  9908
# Winner is  p1
# GAME  9909
# Winner is  p1
# GAME  9910
# Winner is  p1
# GAME  9911
# Winner is  p1
# GAME  9912
# Winner is  p1
# GAME  9913
# Winner is  p1
# GAME  9914
# Winner is  p1
# GAME  9915
# Winner is  p1
# GAME  9916
# Winner is  p1
# GAME  9917
# Winner is  p1
# GAME  9918
# Winner is  p1
# GAME  9919
# Winner is  p1
# GAME  9920
# Winner is  p1
# GAME  9921
# Winner is  p1
# GAME  9922
# Winner is  p1
# GAME  9923
# Winner is  p1
# GAME  9924
# Winner is  p1
# GAME  9925
# Winner is  p1
# GAME  9926
# Winner is  p1
# GAME  9927
# Winner is  p1
# GAME  9928
# Winner is  p1
# GAME  9929
# Winner is  p1
# GAME  9930
# Winner is  p1
# GAME  9931
# Winner is  p1
# GAME  9932
# Winner is  p1
# GAME  9933
# Winner is  p1
# GAME  9934
# Winner is  p1
# GAME  9935
# Winner is  p1
# GAME  9936
# Winner is  p1
# GAME  9937
# Winner is  p1
# GAME  9938
# Winner is  p1
# GAME  9939
# Winner is  p1
# GAME  9940
# Winner is  p1
# GAME  9941
# Winner is  p1
# GAME  9942
# Winner is  p1
# GAME  9943
# Winner is  p1
# GAME  9944
# Winner is  p1
# GAME  9945
# Winner is  p1
# GAME  9946
# Winner is  p1
# GAME  9947
# Winner is  p1
# GAME  9948
# Winner is  p1
# GAME  9949
# Winner is  p1
# GAME  9950
# Winner is  p1
# GAME  9951
# Winner is  p1
# GAME  9952
# Winner is  p1
# GAME  9953
# Winner is  p1
# GAME  9954
# Winner is  p1
# GAME  9955
# Winner is  p1
# GAME  9956
# Winner is  p1
# GAME  9957
# Winner is  p1
# GAME  9958
# Winner is  p1
# GAME  9959
# Winner is  p1
# GAME  9960
# Winner is  p1
# GAME  9961
# Winner is  p1
# GAME  9962
# Winner is  p1
# GAME  9963
# Winner is  p1
# GAME  9964
# Winner is  p1
# GAME  9965
# Winner is  p1
# GAME  9966
# Winner is  p1
# GAME  9967
# Winner is  p1
# GAME  9968
# Winner is  p1
# GAME  9969
# Winner is  p1
# GAME  9970
# Winner is  p1
# GAME  9971
# Winner is  p1
# GAME  9972
# Winner is  p1
# GAME  9973
# Winner is  p1
# GAME  9974
# Winner is  p1
# GAME  9975
# Winner is  p1
# GAME  9976
# Winner is  p1
# GAME  9977
# Winner is  p1
# GAME  9978
# Winner is  p1
# GAME  9979
# Winner is  p1
# GAME  9980
# Winner is  p1
# GAME  9981
# Winner is  p1
# GAME  9982
# Winner is  p1
# GAME  9983
# Winner is  p1
# GAME  9984
# Winner is  p1
# GAME  9985
# Winner is  p1
# GAME  9986
# Winner is  p1
# GAME  9987
# Winner is  p1
# GAME  9988
# Winner is  p1
# GAME  9989
# Winner is  p1
# GAME  9990
# Winner is  p1
# GAME  9991
# Winner is  p1
# GAME  9992
# Winner is  p1
# GAME  9993
# Winner is  p1
# GAME  9994
# Winner is  p1
# GAME  9995
# Winner is  p1
# GAME  9996
# Winner is  p1
# GAME  9997
# Winner is  p1
# GAME  9998
# Winner is  p1
# GAME  9999
# Winner is  p1

# %%
def playAgainstHuman():
  #helper function to play 10 games with human 
  print("Playing with HUMAN")
  print("Enter 1 -> The agent makes the first move")
  print("Enter 2 -> Human makes the first move")
  firstMove=int(input())
  result=playGame(choiceOfMove='qlearner',firstMove=firstMove,withHuman=True)
  return result

wc=0 #win count
lc=0 #lose count
tc=0 #tie count
for i in range(10):
  r=playAgainstHuman() # result is stored in r
  if r=='p1': 
    wc+=1 # our agent p1 wins, update wincount
  elif r=='TIE':
    tc+=1 # game tied. update tiecount
  else:
    lc+=1 # our agent lost, update lose count
print("OUT OF 10 games, win rate = ", wc/10,", tie rate= ",tc/10, ", lose rate= ",lc/10)
# print result
# Out:
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:11
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 |		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 --	 .
#
# 10		 |		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:8
# .	 --	 .	 2	 .
#
# 7		 |		 9
#
# .	 3	 .	 --	 .
#
# 10		 |		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# 7		 |		 9
#
# .	 3	 .	 --	 .
#
# 10		 |		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:12
# .	 --	 .	 --	 .
#
# 7		 |		 9
#
# .	 3	 .	 --	 .
#
# 10		 |		 |
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# 7		 |		 |
#
# .	 3	 .	 --	 .
#
# 10		 |		 |
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# 7		 |		 |
#
# .	 3	 .	 --	 .
#
# 10		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 3	 .	 --	 .
#
# 10		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  0
# Next turn for  human
# Enter the line number:10
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 3	 .	 --	 .
#
# |		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  6
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  8
# Score of  human  is  0
# Winner is  p1
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:3
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 --	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 --	 .	 --	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:9
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:12
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:8
# .	 --	 .	 --	 .
#
# 7		 |		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  2
# Next turn for  human
# Enter the line number:7
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  human
# Enter the line number:11
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# 10		 |		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# 10		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  4
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  4
# TIE
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:2
# .	 --	 .	 --	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:11
# .	 --	 .	 --	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 |		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:3
# .	 --	 .	 --	 .
#
# 7		 8		 9
#
# .	 --	 .	 4	 .
#
# 10		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 --	 .	 4	 .
#
# 10		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:10
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 --	 .	 4	 .
#
# |		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  2
# Next turn for  human
# Enter the line number:8
# .	 --	 .	 --	 .
#
# |		 |		 9
#
# .	 --	 .	 4	 .
#
# |		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  human
# Enter the line number:4
# .	 --	 .	 --	 .
#
# |		 |		 9
#
# .	 --	 .	 --	 .
#
# |		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 9
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  4
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  4
# TIE
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:2
# .	 --	 .	 --	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:6
# .	 --	 .	 --	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:10
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 3	 .	 4	 .
#
# |		 11		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 --	 .	 4	 .
#
# |		 11		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:11
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 --	 .	 4	 .
#
# |		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  2
# Next turn for  human
# Enter the line number:8
# .	 --	 .	 --	 .
#
# |		 |		 9
#
# .	 --	 .	 4	 .
#
# |		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  human
# Enter the line number:4
# .	 --	 .	 --	 .
#
# |		 |		 9
#
# .	 --	 .	 --	 .
#
# |		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 12
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  4
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  4
# TIE
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 2
# Enter the line number:12
# .	 1	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:6
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# |		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:2
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 3	 .	 4	 .
#
# |		 11		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:3
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 --	 .	 4	 .
#
# |		 11		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 --	 .	 4	 .
#
# |		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:11
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 --	 .	 4	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  2
# Next turn for  human
# Enter the line number:4
# .	 --	 .	 --	 .
#
# |		 8		 9
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  human
# Enter the line number:8
# .	 --	 .	 --	 .
#
# |		 |		 9
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  6
# Next turn for  human
# Enter the line number:9
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  8
# Winner is  human
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 2
# Enter the line number:12
# .	 1	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 1	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:4
# .	 1	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 --	 .
#
# 10		 11		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 1	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 --	 .
#
# 10		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 --	 .
#
# 10		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  0
# Next turn for  human
# Enter the line number:7
# .	 --	 .	 2	 .
#
# |		 8		 9
#
# .	 3	 .	 --	 .
#
# 10		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# |		 |		 9
#
# .	 3	 .	 --	 .
#
# 10		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  0
# Next turn for  human
# Enter the line number:3
# .	 --	 .	 2	 .
#
# |		 |		 9
#
# .	 --	 .	 --	 .
#
# 10		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  2
# Next turn for  human
# Enter the line number:10
# .	 --	 .	 2	 .
#
# |		 |		 9
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 5	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  2
# Next turn for  p1
# .	 --	 .	 2	 .
#
# |		 |		 9
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  2
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 9
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  2
# Next turn for  human
# Enter the line number:9
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  4
# TIE
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 2
# Enter the line number:7
# .	 1	 .	 2	 .
#
# |		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 1	 .	 2	 .
#
# |		 |		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:5
# .	 1	 .	 2	 .
#
# |		 |		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 1	 .	 2	 .
#
# |		 |		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:6
# .	 1	 .	 2	 .
#
# |		 |		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 1	 .	 2	 .
#
# |		 |		 |
#
# .	 3	 .	 4	 .
#
# 10		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:10
# .	 1	 .	 2	 .
#
# |		 |		 |
#
# .	 3	 .	 4	 .
#
# |		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# |		 |		 |
#
# .	 3	 .	 4	 .
#
# |		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:3
# .	 --	 .	 2	 .
#
# |		 |		 |
#
# .	 --	 .	 4	 .
#
# |		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  2
# Next turn for  human
# Enter the line number:11
# .	 --	 .	 2	 .
#
# |		 |		 |
#
# .	 --	 .	 4	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  human
# Enter the line number:4
# .	 --	 .	 2	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  6
# Next turn for  human
# Enter the line number:2
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  8
# Winner is  human
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 4
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:9
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:2
# .	 --	 .	 --	 .
#
# 7		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# 7		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:12
# .	 --	 .	 --	 .
#
# 7		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:6
# .	 --	 .	 --	 .
#
# |		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# 10		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  6
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  8
# Score of  human  is  0
# Winner is  p1
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:9
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:12
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 |
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 |
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:5
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# 10		 11		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:11
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# 10		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  2
# Next turn for  human
# Enter the line number:10
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  human
# Enter the line number:2
# .	 --	 .	 --	 .
#
# 7		 8		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  4
# Next turn for  p1
# .	 --	 .	 --	 .
#
# 7		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  4
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  4
# TIE
# Playing with HUMAN
# Enter 1 -> The agent makes the first move
# Enter 2 -> Human makes the first move
# 1
# .	 --	 .	 2	 .
#
# 7		 8		 9
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:9
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 3	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 11		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:11
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 |		 12
#
# .	 5	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# 7		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 |		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  human
# Enter the line number:7
# .	 --	 .	 2	 .
#
# |		 8		 |
#
# .	 --	 .	 4	 .
#
# 10		 |		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  0
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# |		 8		 |
#
# .	 --	 .	 4	 .
#
# |		 |		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  2
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 2	 .
#
# |		 |		 |
#
# .	 --	 .	 4	 .
#
# |		 |		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  0
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 4	 .
#
# |		 |		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  0
# Next turn for  human
# Enter the line number:4
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 12
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  2
# Next turn for  human
# Enter the line number:12
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 6	 .
#
#
#
# Score of  p1  is  4
# Score of  human  is  2
# Next turn for  p1
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
# |		 |		 |
#
# .	 --	 .	 --	 .
#
#
#
# Score of  p1  is  6
# Score of  human  is  2
# Winner is  p1
# OUT OF 10 games, win rate =  0.3 , tie rate=  0.5 , lose rate=  0.2

# %% [markdown]
# ### Save the QTABLE and print visit table

# %%
#save in json file
with open('Qtable.json','w') as jsonfile:
  json.dump(QTable,jsonfile)

# print(VISIT_TABLE)
# OPTIONAL to print and check if all states are visited

# %% [markdown]
# ## Check the performance of our machine by letting it play N games with random agent and find its winrate

# %%
'''
JUST like the play game function, altered to make 2 different agents play, agent qlearner against random or itself etc. 
'''
def playGame_AgentVsAgent(opponent='random'):
    #specify opponent for qlearner to play with
    #Game init
    player=["p1","p2"]    
    #players p1, p2
    currentPlayer="p1"
    box=[0,0,0,0]
    # Which are boxes completed. It is updated to keep score
    currentState=BitArray(uint=0, length=12)
    # INITIAL board state
    memory={player[0]:[],player[1]:[]}
    score={player[0]:0,player[1]:0}
    # INITIALISE memory of a game and score
    while isBoardStateFinal(currentState)==False:  # while the game is not over
        if(currentPlayer=="p1"):
          currentMove=MakeMove(currentState.bin,'qlearner')
        else:
          currentMove=MakeMove(currentState.bin,opponent)
          
         # Transition is made with the move
        newState=transition(currentState.bin,currentMove) 
        # Memory of the current move is added to player game memory
        memory[currentPlayer].append([currentState.bin,currentMove,newState,0])
        # Checks if new box is formed, if so score is updated
        numberOfBoxes=numberOfNewBoxFormed(box,newState)
        if numberOfBoxes>0:#Short term rewards are given for boxes and score is updated
            score[currentPlayer]+=numberOfBoxes*2
            memory[currentPlayer][-1][-1]=100
            memory[player[1-player.index(currentPlayer)]][-1][-1]=-100

        else: #toggle the current player to give the turn to next player
            currentPlayer=player[1-player.index(currentPlayer)]

        currentState=BitArray(uint=int(newState,2),length=12)
        #update current state based on the transition obtained
        
    #find winner game over now
    result=""
    if score[player[0]]==score[player[1]]:
        result='TIE'
        print(result)
    else:
        result=max(score,key=score.get)
        print("Winner is ",result)
    #print(memory[player[0]])
    if result=='TIE':
        memory[player[0]][-1][-1]=50
        memory[player[1]][-1][-1]=50
    else: 
        memory[result][-1][-1]=200
        memory[player[1-player.index(result)]][-1][-1]=-200    
    #put reward and penalties in last row of the memory table
    updateQTable(memory[player[0]])
    updateQTable(memory[player[1]])
    # update the QTABLE 
    return result

# %%
winCount=0 #agent against agent wincount
loseCount=0 #agent against agent losecount
N=1000
for i in range(1,N+1):
  #play qlearner vs random
  winner = playGame_AgentVsAgent(opponent='random')
  
  print('Game ',i," : Winner is ",winner)
  #print winner of game
  if winner =='p1':
    winCount+=1
  if winner =='p2':
    loseCount+=1

#print metric
print("Of the ",N," games, our Q Learner  has winrate =",winCount/N," and loserate =",loseCount/N,". It has tie rate of  ", (N-winCount-loseCount)/N ) #N-win-lose gives tie count
# Out:
# Winner is  p1
# Game  1  : Winner is  p1
# TIE
# Game  2  : Winner is  TIE
# Winner is  p1
# Game  3  : Winner is  p1
# Winner is  p1
# Game  4  : Winner is  p1
# Winner is  p1
# Game  5  : Winner is  p1
# Winner is  p1
# Game  6  : Winner is  p1
# TIE
# Game  7  : Winner is  TIE
# Winner is  p1
# Game  8  : Winner is  p1
# Winner is  p1
# Game  9  : Winner is  p1
# Winner is  p1
# Game  10  : Winner is  p1
# Winner is  p1
# Game  11  : Winner is  p1
# Winner is  p1
# Game  12  : Winner is  p1
# Winner is  p1
# Game  13  : Winner is  p1
# Winner is  p1
# Game  14  : Winner is  p1
# Winner is  p1
# Game  15  : Winner is  p1
# Winner is  p1
# Game  16  : Winner is  p1
# Winner is  p1
# Game  17  : Winner is  p1
# Winner is  p1
# Game  18  : Winner is  p1
# Winner is  p1
# Game  19  : Winner is  p1
# Winner is  p1
# Game  20  : Winner is  p1
# Winner is  p1
# Game  21  : Winner is  p1
# Winner is  p1
# Game  22  : Winner is  p1
# Winner is  p1
# Game  23  : Winner is  p1
# Winner is  p1
# Game  24  : Winner is  p1
# Winner is  p1
# Game  25  : Winner is  p1
# Winner is  p1
# Game  26  : Winner is  p1
# TIE
# Game  27  : Winner is  TIE
# Winner is  p1
# Game  28  : Winner is  p1
# Winner is  p1
# Game  29  : Winner is  p1
# Winner is  p1
# Game  30  : Winner is  p1
# TIE
# Game  31  : Winner is  TIE
# Winner is  p1
# Game  32  : Winner is  p1
# Winner is  p1
# Game  33  : Winner is  p1
# Winner is  p1
# Game  34  : Winner is  p1
# Winner is  p1
# Game  35  : Winner is  p1
# Winner is  p1
# Game  36  : Winner is  p1
# Winner is  p1
# Game  37  : Winner is  p1
# Winner is  p1
# Game  38  : Winner is  p1
# Winner is  p1
# Game  39  : Winner is  p1
# Winner is  p1
# Game  40  : Winner is  p1
# Winner is  p1
# Game  41  : Winner is  p1
# Winner is  p1
# Game  42  : Winner is  p1
# Winner is  p1
# Game  43  : Winner is  p1
# TIE
# Game  44  : Winner is  TIE
# Winner is  p1
# Game  45  : Winner is  p1
# Winner is  p1
# Game  46  : Winner is  p1
# Winner is  p1
# Game  47  : Winner is  p1
# Winner is  p1
# Game  48  : Winner is  p1
# Winner is  p1
# Game  49  : Winner is  p1
# Winner is  p1
# Game  50  : Winner is  p1
# TIE
# Game  51  : Winner is  TIE
# Winner is  p1
# Game  52  : Winner is  p1
# Winner is  p1
# Game  53  : Winner is  p1
# Winner is  p1
# Game  54  : Winner is  p1
# Winner is  p1
# Game  55  : Winner is  p1
# Winner is  p1
# Game  56  : Winner is  p1
# Winner is  p1
# Game  57  : Winner is  p1
# Winner is  p1
# Game  58  : Winner is  p1
# TIE
# Game  59  : Winner is  TIE
# Winner is  p1
# Game  60  : Winner is  p1
# Winner is  p1
# Game  61  : Winner is  p1
# Winner is  p1
# Game  62  : Winner is  p1
# Winner is  p1
# Game  63  : Winner is  p1
# Winner is  p1
# Game  64  : Winner is  p1
# Winner is  p1
# Game  65  : Winner is  p1
# Winner is  p1
# Game  66  : Winner is  p1
# Winner is  p1
# Game  67  : Winner is  p1
# Winner is  p1
# Game  68  : Winner is  p1
# Winner is  p1
# Game  69  : Winner is  p1
# Winner is  p1
# Game  70  : Winner is  p1
# Winner is  p1
# Game  71  : Winner is  p1
# Winner is  p1
# Game  72  : Winner is  p1
# TIE
# Game  73  : Winner is  TIE
# Winner is  p1
# Game  74  : Winner is  p1
# Winner is  p1
# Game  75  : Winner is  p1
# Winner is  p1
# Game  76  : Winner is  p1
# Winner is  p1
# Game  77  : Winner is  p1
# Winner is  p1
# Game  78  : Winner is  p1
# Winner is  p1
# Game  79  : Winner is  p1
# Winner is  p1
# Game  80  : Winner is  p1
# Winner is  p1
# Game  81  : Winner is  p1
# Winner is  p1
# Game  82  : Winner is  p1
# Winner is  p1
# Game  83  : Winner is  p1
# Winner is  p1
# Game  84  : Winner is  p1
# Winner is  p1
# Game  85  : Winner is  p1
# Winner is  p1
# Game  86  : Winner is  p1
# Winner is  p1
# Game  87  : Winner is  p1
# Winner is  p1
# Game  88  : Winner is  p1
# Winner is  p1
# Game  89  : Winner is  p1
# Winner is  p1
# Game  90  : Winner is  p1
# Winner is  p1
# Game  91  : Winner is  p1
# Winner is  p1
# Game  92  : Winner is  p1
# Winner is  p1
# Game  93  : Winner is  p1
# Winner is  p1
# Game  94  : Winner is  p1
# Winner is  p1
# Game  95  : Winner is  p1
# TIE
# Game  96  : Winner is  TIE
# Winner is  p1
# Game  97  : Winner is  p1
# Winner is  p1
# Game  98  : Winner is  p1
# Winner is  p1
# Game  99  : Winner is  p1
# Winner is  p1
# Game  100  : Winner is  p1
# Winner is  p1
# Game  101  : Winner is  p1
# Winner is  p1
# Game  102  : Winner is  p1
# Winner is  p1
# Game  103  : Winner is  p1
# Winner is  p1
# Game  104  : Winner is  p1
# Winner is  p1
# Game  105  : Winner is  p1
# Winner is  p1
# Game  106  : Winner is  p1
# Winner is  p1
# Game  107  : Winner is  p1
# Winner is  p1
# Game  108  : Winner is  p1
# TIE
# Game  109  : Winner is  TIE
# Winner is  p1
# Game  110  : Winner is  p1
# Winner is  p1
# Game  111  : Winner is  p1
# Winner is  p1
# Game  112  : Winner is  p1
# Winner is  p1
# Game  113  : Winner is  p1
# Winner is  p1
# Game  114  : Winner is  p1
# Winner is  p1
# Game  115  : Winner is  p1
# Winner is  p1
# Game  116  : Winner is  p1
# TIE
# Game  117  : Winner is  TIE
# Winner is  p1
# Game  118  : Winner is  p1
# Winner is  p1
# Game  119  : Winner is  p1
# Winner is  p1
# Game  120  : Winner is  p1
# Winner is  p1
# Game  121  : Winner is  p1
# Winner is  p1
# Game  122  : Winner is  p1
# Winner is  p1
# Game  123  : Winner is  p1
# Winner is  p1
# Game  124  : Winner is  p1
# Winner is  p1
# Game  125  : Winner is  p1
# Winner is  p1
# Game  126  : Winner is  p1
# Winner is  p1
# Game  127  : Winner is  p1
# Winner is  p1
# Game  128  : Winner is  p1
# Winner is  p1
# Game  129  : Winner is  p1
# Winner is  p1
# Game  130  : Winner is  p1
# Winner is  p1
# Game  131  : Winner is  p1
# Winner is  p1
# Game  132  : Winner is  p1
# Winner is  p1
# Game  133  : Winner is  p1
# Winner is  p1
# Game  134  : Winner is  p1
# Winner is  p1
# Game  135  : Winner is  p1
# Winner is  p1
# Game  136  : Winner is  p1
# Winner is  p1
# Game  137  : Winner is  p1
# Winner is  p1
# Game  138  : Winner is  p1
# Winner is  p1
# Game  139  : Winner is  p1
# Winner is  p1
# Game  140  : Winner is  p1
# Winner is  p1
# Game  141  : Winner is  p1
# Winner is  p1
# Game  142  : Winner is  p1
# Winner is  p1
# Game  143  : Winner is  p1
# Winner is  p1
# Game  144  : Winner is  p1
# Winner is  p1
# Game  145  : Winner is  p1
# Winner is  p1
# Game  146  : Winner is  p1
# Winner is  p1
# Game  147  : Winner is  p1
# Winner is  p2
# Game  148  : Winner is  p2
# Winner is  p1
# Game  149  : Winner is  p1
# Winner is  p1
# Game  150  : Winner is  p1
# Winner is  p1
# Game  151  : Winner is  p1
# Winner is  p1
# Game  152  : Winner is  p1
# Winner is  p1
# Game  153  : Winner is  p1
# Winner is  p1
# Game  154  : Winner is  p1
# Winner is  p1
# Game  155  : Winner is  p1
# Winner is  p1
# Game  156  : Winner is  p1
# Winner is  p1
# Game  157  : Winner is  p1
# Winner is  p1
# Game  158  : Winner is  p1
# Winner is  p1
# Game  159  : Winner is  p1
# Winner is  p1
# Game  160  : Winner is  p1
# Winner is  p1
# Game  161  : Winner is  p1
# Winner is  p1
# Game  162  : Winner is  p1
# Winner is  p1
# Game  163  : Winner is  p1
# Winner is  p1
# Game  164  : Winner is  p1
# Winner is  p1
# Game  165  : Winner is  p1
# Winner is  p1
# Game  166  : Winner is  p1
# Winner is  p1
# Game  167  : Winner is  p1
# Winner is  p1
# Game  168  : Winner is  p1
# Winner is  p1
# Game  169  : Winner is  p1
# Winner is  p1
# Game  170  : Winner is  p1
# Winner is  p1
# Game  171  : Winner is  p1
# TIE
# Game  172  : Winner is  TIE
# Winner is  p1
# Game  173  : Winner is  p1
# Winner is  p1
# Game  174  : Winner is  p1
# TIE
# Game  175  : Winner is  TIE
# Winner is  p1
# Game  176  : Winner is  p1
# Winner is  p1
# Game  177  : Winner is  p1
# Winner is  p1
# Game  178  : Winner is  p1
# Winner is  p1
# Game  179  : Winner is  p1
# Winner is  p1
# Game  180  : Winner is  p1
# Winner is  p1
# Game  181  : Winner is  p1
# Winner is  p1
# Game  182  : Winner is  p1
# Winner is  p1
# Game  183  : Winner is  p1
# Winner is  p1
# Game  184  : Winner is  p1
# Winner is  p1
# Game  185  : Winner is  p1
# Winner is  p1
# Game  186  : Winner is  p1
# Winner is  p1
# Game  187  : Winner is  p1
# Winner is  p1
# Game  188  : Winner is  p1
# Winner is  p1
# Game  189  : Winner is  p1
# Winner is  p1
# Game  190  : Winner is  p1
# Winner is  p1
# Game  191  : Winner is  p1
# Winner is  p1
# Game  192  : Winner is  p1
# Winner is  p1
# Game  193  : Winner is  p1
# Winner is  p1
# Game  194  : Winner is  p1
# Winner is  p1
# Game  195  : Winner is  p1
# Winner is  p1
# Game  196  : Winner is  p1
# Winner is  p1
# Game  197  : Winner is  p1
# Winner is  p1
# Game  198  : Winner is  p1
# Winner is  p1
# Game  199  : Winner is  p1
# Winner is  p1
# Game  200  : Winner is  p1
# Winner is  p1
# Game  201  : Winner is  p1
# Winner is  p1
# Game  202  : Winner is  p1
# Winner is  p1
# Game  203  : Winner is  p1
# Winner is  p1
# Game  204  : Winner is  p1
# Winner is  p1
# Game  205  : Winner is  p1
# Winner is  p1
# Game  206  : Winner is  p1
# Winner is  p2
# Game  207  : Winner is  p2
# Winner is  p1
# Game  208  : Winner is  p1
# Winner is  p1
# Game  209  : Winner is  p1
# Winner is  p1
# Game  210  : Winner is  p1
# Winner is  p1
# Game  211  : Winner is  p1
# Winner is  p1
# Game  212  : Winner is  p1
# TIE
# Game  213  : Winner is  TIE
# Winner is  p1
# Game  214  : Winner is  p1
# TIE
# Game  215  : Winner is  TIE
# Winner is  p1
# Game  216  : Winner is  p1
# Winner is  p1
# Game  217  : Winner is  p1
# Winner is  p1
# Game  218  : Winner is  p1
# Winner is  p1
# Game  219  : Winner is  p1
# Winner is  p1
# Game  220  : Winner is  p1
# Winner is  p1
# Game  221  : Winner is  p1
# Winner is  p1
# Game  222  : Winner is  p1
# TIE
# Game  223  : Winner is  TIE
# Winner is  p1
# Game  224  : Winner is  p1
# Winner is  p1
# Game  225  : Winner is  p1
# Winner is  p1
# Game  226  : Winner is  p1
# Winner is  p1
# Game  227  : Winner is  p1
# Winner is  p1
# Game  228  : Winner is  p1
# Winner is  p1
# Game  229  : Winner is  p1
# Winner is  p1
# Game  230  : Winner is  p1
# Winner is  p1
# Game  231  : Winner is  p1
# Winner is  p1
# Game  232  : Winner is  p1
# Winner is  p1
# Game  233  : Winner is  p1
# Winner is  p1
# Game  234  : Winner is  p1
# Winner is  p1
# Game  235  : Winner is  p1
# Winner is  p1
# Game  236  : Winner is  p1
# Winner is  p1
# Game  237  : Winner is  p1
# Winner is  p1
# Game  238  : Winner is  p1
# Winner is  p1
# Game  239  : Winner is  p1
# Winner is  p1
# Game  240  : Winner is  p1
# Winner is  p1
# Game  241  : Winner is  p1
# Winner is  p1
# Game  242  : Winner is  p1
# Winner is  p1
# Game  243  : Winner is  p1
# Winner is  p1
# Game  244  : Winner is  p1
# Winner is  p1
# Game  245  : Winner is  p1
# Winner is  p1
# Game  246  : Winner is  p1
# Winner is  p1
# Game  247  : Winner is  p1
# Winner is  p1
# Game  248  : Winner is  p1
# Winner is  p1
# Game  249  : Winner is  p1
# Winner is  p1
# Game  250  : Winner is  p1
# Winner is  p1
# Game  251  : Winner is  p1
# Winner is  p1
# Game  252  : Winner is  p1
# Winner is  p1
# Game  253  : Winner is  p1
# Winner is  p1
# Game  254  : Winner is  p1
# Winner is  p1
# Game  255  : Winner is  p1
# Winner is  p1
# Game  256  : Winner is  p1
# Winner is  p1
# Game  257  : Winner is  p1
# Winner is  p1
# Game  258  : Winner is  p1
# TIE
# Game  259  : Winner is  TIE
# Winner is  p1
# Game  260  : Winner is  p1
# Winner is  p1
# Game  261  : Winner is  p1
# Winner is  p1
# Game  262  : Winner is  p1
# Winner is  p1
# Game  263  : Winner is  p1
# Winner is  p1
# Game  264  : Winner is  p1
# Winner is  p1
# Game  265  : Winner is  p1
# TIE
# Game  266  : Winner is  TIE
# Winner is  p1
# Game  267  : Winner is  p1
# Winner is  p1
# Game  268  : Winner is  p1
# Winner is  p1
# Game  269  : Winner is  p1
# Winner is  p1
# Game  270  : Winner is  p1
# Winner is  p1
# Game  271  : Winner is  p1
# Winner is  p1
# Game  272  : Winner is  p1
# Winner is  p1
# Game  273  : Winner is  p1
# Winner is  p1
# Game  274  : Winner is  p1
# Winner is  p2
# Game  275  : Winner is  p2
# Winner is  p1
# Game  276  : Winner is  p1
# Winner is  p1
# Game  277  : Winner is  p1
# Winner is  p1
# Game  278  : Winner is  p1
# Winner is  p1
# Game  279  : Winner is  p1
# Winner is  p1
# Game  280  : Winner is  p1
# Winner is  p1
# Game  281  : Winner is  p1
# Winner is  p1
# Game  282  : Winner is  p1
# Winner is  p1
# Game  283  : Winner is  p1
# Winner is  p1
# Game  284  : Winner is  p1
# Winner is  p1
# Game  285  : Winner is  p1
# Winner is  p1
# Game  286  : Winner is  p1
# Winner is  p1
# Game  287  : Winner is  p1
# Winner is  p1
# Game  288  : Winner is  p1
# Winner is  p1
# Game  289  : Winner is  p1
# Winner is  p1
# Game  290  : Winner is  p1
# Winner is  p1
# Game  291  : Winner is  p1
# Winner is  p1
# Game  292  : Winner is  p1
# Winner is  p1
# Game  293  : Winner is  p1
# Winner is  p1
# Game  294  : Winner is  p1
# Winner is  p1
# Game  295  : Winner is  p1
# Winner is  p1
# Game  296  : Winner is  p1
# Winner is  p1
# Game  297  : Winner is  p1
# Winner is  p1
# Game  298  : Winner is  p1
# Winner is  p1
# Game  299  : Winner is  p1
# Winner is  p1
# Game  300  : Winner is  p1
# Winner is  p1
# Game  301  : Winner is  p1
# Winner is  p1
# Game  302  : Winner is  p1
# Winner is  p1
# Game  303  : Winner is  p1
# Winner is  p1
# Game  304  : Winner is  p1
# Winner is  p1
# Game  305  : Winner is  p1
# Winner is  p1
# Game  306  : Winner is  p1
# Winner is  p1
# Game  307  : Winner is  p1
# Winner is  p1
# Game  308  : Winner is  p1
# Winner is  p1
# Game  309  : Winner is  p1
# Winner is  p1
# Game  310  : Winner is  p1
# Winner is  p1
# Game  311  : Winner is  p1
# Winner is  p1
# Game  312  : Winner is  p1
# Winner is  p1
# Game  313  : Winner is  p1
# Winner is  p1
# Game  314  : Winner is  p1
# Winner is  p1
# Game  315  : Winner is  p1
# Winner is  p1
# Game  316  : Winner is  p1
# Winner is  p1
# Game  317  : Winner is  p1
# Winner is  p1
# Game  318  : Winner is  p1
# TIE
# Game  319  : Winner is  TIE
# Winner is  p1
# Game  320  : Winner is  p1
# Winner is  p1
# Game  321  : Winner is  p1
# Winner is  p1
# Game  322  : Winner is  p1
# Winner is  p1
# Game  323  : Winner is  p1
# Winner is  p1
# Game  324  : Winner is  p1
# Winner is  p1
# Game  325  : Winner is  p1
# Winner is  p1
# Game  326  : Winner is  p1
# Winner is  p1
# Game  327  : Winner is  p1
# Winner is  p1
# Game  328  : Winner is  p1
# Winner is  p1
# Game  329  : Winner is  p1
# Winner is  p1
# Game  330  : Winner is  p1
# Winner is  p1
# Game  331  : Winner is  p1
# Winner is  p1
# Game  332  : Winner is  p1
# TIE
# Game  333  : Winner is  TIE
# Winner is  p1
# Game  334  : Winner is  p1
# Winner is  p1
# Game  335  : Winner is  p1
# Winner is  p1
# Game  336  : Winner is  p1
# TIE
# Game  337  : Winner is  TIE
# Winner is  p1
# Game  338  : Winner is  p1
# Winner is  p1
# Game  339  : Winner is  p1
# Winner is  p1
# Game  340  : Winner is  p1
# TIE
# Game  341  : Winner is  TIE
# Winner is  p1
# Game  342  : Winner is  p1
# Winner is  p1
# Game  343  : Winner is  p1
# Winner is  p1
# Game  344  : Winner is  p1
# Winner is  p1
# Game  345  : Winner is  p1
# Winner is  p1
# Game  346  : Winner is  p1
# Winner is  p1
# Game  347  : Winner is  p1
# Winner is  p1
# Game  348  : Winner is  p1
# Winner is  p1
# Game  349  : Winner is  p1
# Winner is  p1
# Game  350  : Winner is  p1
# Winner is  p1
# Game  351  : Winner is  p1
# Winner is  p1
# Game  352  : Winner is  p1
# Winner is  p1
# Game  353  : Winner is  p1
# Winner is  p1
# Game  354  : Winner is  p1
# Winner is  p1
# Game  355  : Winner is  p1
# Winner is  p1
# Game  356  : Winner is  p1
# Winner is  p1
# Game  357  : Winner is  p1
# Winner is  p1
# Game  358  : Winner is  p1
# Winner is  p1
# Game  359  : Winner is  p1
# Winner is  p1
# Game  360  : Winner is  p1
# Winner is  p1
# Game  361  : Winner is  p1
# Winner is  p1
# Game  362  : Winner is  p1
# Winner is  p1
# Game  363  : Winner is  p1
# Winner is  p1
# Game  364  : Winner is  p1
# Winner is  p1
# Game  365  : Winner is  p1
# Winner is  p1
# Game  366  : Winner is  p1
# Winner is  p1
# Game  367  : Winner is  p1
# Winner is  p1
# Game  368  : Winner is  p1
# Winner is  p1
# Game  369  : Winner is  p1
# Winner is  p1
# Game  370  : Winner is  p1
# Winner is  p1
# Game  371  : Winner is  p1
# Winner is  p1
# Game  372  : Winner is  p1
# Winner is  p1
# Game  373  : Winner is  p1
# Winner is  p1
# Game  374  : Winner is  p1
# Winner is  p1
# Game  375  : Winner is  p1
# Winner is  p1
# Game  376  : Winner is  p1
# Winner is  p1
# Game  377  : Winner is  p1
# Winner is  p1
# Game  378  : Winner is  p1
# Winner is  p1
# Game  379  : Winner is  p1
# Winner is  p1
# Game  380  : Winner is  p1
# Winner is  p1
# Game  381  : Winner is  p1
# Winner is  p1
# Game  382  : Winner is  p1
# Winner is  p1
# Game  383  : Winner is  p1
# Winner is  p1
# Game  384  : Winner is  p1
# Winner is  p1
# Game  385  : Winner is  p1
# Winner is  p1
# Game  386  : Winner is  p1
# Winner is  p1
# Game  387  : Winner is  p1
# Winner is  p1
# Game  388  : Winner is  p1
# Winner is  p1
# Game  389  : Winner is  p1
# Winner is  p1
# Game  390  : Winner is  p1
# Winner is  p1
# Game  391  : Winner is  p1
# Winner is  p1
# Game  392  : Winner is  p1
# Winner is  p1
# Game  393  : Winner is  p1
# Winner is  p1
# Game  394  : Winner is  p1
# Winner is  p1
# Game  395  : Winner is  p1
# Winner is  p1
# Game  396  : Winner is  p1
# Winner is  p2
# Game  397  : Winner is  p2
# Winner is  p1
# Game  398  : Winner is  p1
# Winner is  p1
# Game  399  : Winner is  p1
# Winner is  p1
# Game  400  : Winner is  p1
# Winner is  p1
# Game  401  : Winner is  p1
# Winner is  p1
# Game  402  : Winner is  p1
# Winner is  p1
# Game  403  : Winner is  p1
# Winner is  p1
# Game  404  : Winner is  p1
# Winner is  p1
# Game  405  : Winner is  p1
# Winner is  p1
# Game  406  : Winner is  p1
# Winner is  p1
# Game  407  : Winner is  p1
# Winner is  p2
# Game  408  : Winner is  p2
# Winner is  p1
# Game  409  : Winner is  p1
# Winner is  p1
# Game  410  : Winner is  p1
# Winner is  p1
# Game  411  : Winner is  p1
# Winner is  p1
# Game  412  : Winner is  p1
# Winner is  p1
# Game  413  : Winner is  p1
# Winner is  p1
# Game  414  : Winner is  p1
# Winner is  p1
# Game  415  : Winner is  p1
# Winner is  p1
# Game  416  : Winner is  p1
# TIE
# Game  417  : Winner is  TIE
# Winner is  p1
# Game  418  : Winner is  p1
# Winner is  p1
# Game  419  : Winner is  p1
# Winner is  p1
# Game  420  : Winner is  p1
# Winner is  p1
# Game  421  : Winner is  p1
# Winner is  p1
# Game  422  : Winner is  p1
# Winner is  p1
# Game  423  : Winner is  p1
# Winner is  p1
# Game  424  : Winner is  p1
# Winner is  p1
# Game  425  : Winner is  p1
# Winner is  p1
# Game  426  : Winner is  p1
# Winner is  p1
# Game  427  : Winner is  p1
# Winner is  p1
# Game  428  : Winner is  p1
# Winner is  p1
# Game  429  : Winner is  p1
# Winner is  p1
# Game  430  : Winner is  p1
# Winner is  p1
# Game  431  : Winner is  p1
# Winner is  p1
# Game  432  : Winner is  p1
# Winner is  p1
# Game  433  : Winner is  p1
# Winner is  p1
# Game  434  : Winner is  p1
# Winner is  p1
# Game  435  : Winner is  p1
# TIE
# Game  436  : Winner is  TIE
# Winner is  p1
# Game  437  : Winner is  p1
# Winner is  p1
# Game  438  : Winner is  p1
# Winner is  p1
# Game  439  : Winner is  p1
# Winner is  p1
# Game  440  : Winner is  p1
# Winner is  p1
# Game  441  : Winner is  p1
# Winner is  p1
# Game  442  : Winner is  p1
# Winner is  p1
# Game  443  : Winner is  p1
# TIE
# Game  444  : Winner is  TIE
# Winner is  p1
# Game  445  : Winner is  p1
# Winner is  p1
# Game  446  : Winner is  p1
# Winner is  p1
# Game  447  : Winner is  p1
# Winner is  p1
# Game  448  : Winner is  p1
# Winner is  p1
# Game  449  : Winner is  p1
# Winner is  p1
# Game  450  : Winner is  p1
# Winner is  p1
# Game  451  : Winner is  p1
# Winner is  p1
# Game  452  : Winner is  p1
# Winner is  p1
# Game  453  : Winner is  p1
# Winner is  p1
# Game  454  : Winner is  p1
# Winner is  p1
# Game  455  : Winner is  p1
# TIE
# Game  456  : Winner is  TIE
# Winner is  p1
# Game  457  : Winner is  p1
# Winner is  p1
# Game  458  : Winner is  p1
# Winner is  p1
# Game  459  : Winner is  p1
# Winner is  p1
# Game  460  : Winner is  p1
# Winner is  p1
# Game  461  : Winner is  p1
# Winner is  p1
# Game  462  : Winner is  p1
# Winner is  p1
# Game  463  : Winner is  p1
# Winner is  p1
# Game  464  : Winner is  p1
# Winner is  p1
# Game  465  : Winner is  p1
# Winner is  p1
# Game  466  : Winner is  p1
# Winner is  p1
# Game  467  : Winner is  p1
# Winner is  p1
# Game  468  : Winner is  p1
# Winner is  p1
# Game  469  : Winner is  p1
# Winner is  p1
# Game  470  : Winner is  p1
# Winner is  p1
# Game  471  : Winner is  p1
# Winner is  p1
# Game  472  : Winner is  p1
# Winner is  p1
# Game  473  : Winner is  p1
# Winner is  p1
# Game  474  : Winner is  p1
# Winner is  p1
# Game  475  : Winner is  p1
# Winner is  p1
# Game  476  : Winner is  p1
# Winner is  p1
# Game  477  : Winner is  p1
# Winner is  p1
# Game  478  : Winner is  p1
# Winner is  p2
# Game  479  : Winner is  p2
# Winner is  p1
# Game  480  : Winner is  p1
# TIE
# Game  481  : Winner is  TIE
# Winner is  p1
# Game  482  : Winner is  p1
# Winner is  p1
# Game  483  : Winner is  p1
# Winner is  p1
# Game  484  : Winner is  p1
# Winner is  p1
# Game  485  : Winner is  p1
# Winner is  p1
# Game  486  : Winner is  p1
# Winner is  p1
# Game  487  : Winner is  p1
# Winner is  p1
# Game  488  : Winner is  p1
# Winner is  p1
# Game  489  : Winner is  p1
# Winner is  p1
# Game  490  : Winner is  p1
# Winner is  p1
# Game  491  : Winner is  p1
# Winner is  p1
# Game  492  : Winner is  p1
# Winner is  p1
# Game  493  : Winner is  p1
# Winner is  p1
# Game  494  : Winner is  p1
# Winner is  p1
# Game  495  : Winner is  p1
# Winner is  p1
# Game  496  : Winner is  p1
# Winner is  p1
# Game  497  : Winner is  p1
# Winner is  p1
# Game  498  : Winner is  p1
# Winner is  p1
# Game  499  : Winner is  p1
# Winner is  p1
# Game  500  : Winner is  p1
# Winner is  p1
# Game  501  : Winner is  p1
# Winner is  p1
# Game  502  : Winner is  p1
# Winner is  p1
# Game  503  : Winner is  p1
# Winner is  p1
# Game  504  : Winner is  p1
# Winner is  p1
# Game  505  : Winner is  p1
# Winner is  p1
# Game  506  : Winner is  p1
# Winner is  p1
# Game  507  : Winner is  p1
# Winner is  p1
# Game  508  : Winner is  p1
# Winner is  p1
# Game  509  : Winner is  p1
# Winner is  p1
# Game  510  : Winner is  p1
# Winner is  p1
# Game  511  : Winner is  p1
# Winner is  p1
# Game  512  : Winner is  p1
# Winner is  p1
# Game  513  : Winner is  p1
# Winner is  p1
# Game  514  : Winner is  p1
# TIE
# Game  515  : Winner is  TIE
# Winner is  p1
# Game  516  : Winner is  p1
# Winner is  p1
# Game  517  : Winner is  p1
# Winner is  p1
# Game  518  : Winner is  p1
# Winner is  p1
# Game  519  : Winner is  p1
# Winner is  p1
# Game  520  : Winner is  p1
# TIE
# Game  521  : Winner is  TIE
# Winner is  p1
# Game  522  : Winner is  p1
# Winner is  p1
# Game  523  : Winner is  p1
# Winner is  p1
# Game  524  : Winner is  p1
# Winner is  p1
# Game  525  : Winner is  p1
# Winner is  p1
# Game  526  : Winner is  p1
# Winner is  p1
# Game  527  : Winner is  p1
# TIE
# Game  528  : Winner is  TIE
# Winner is  p1
# Game  529  : Winner is  p1
# Winner is  p1
# Game  530  : Winner is  p1
# Winner is  p1
# Game  531  : Winner is  p1
# Winner is  p1
# Game  532  : Winner is  p1
# Winner is  p1
# Game  533  : Winner is  p1
# Winner is  p1
# Game  534  : Winner is  p1
# Winner is  p1
# Game  535  : Winner is  p1
# Winner is  p1
# Game  536  : Winner is  p1
# Winner is  p1
# Game  537  : Winner is  p1
# Winner is  p1
# Game  538  : Winner is  p1
# Winner is  p1
# Game  539  : Winner is  p1
# Winner is  p1
# Game  540  : Winner is  p1
# Winner is  p1
# Game  541  : Winner is  p1
# Winner is  p1
# Game  542  : Winner is  p1
# Winner is  p1
# Game  543  : Winner is  p1
# Winner is  p1
# Game  544  : Winner is  p1
# Winner is  p1
# Game  545  : Winner is  p1
# Winner is  p1
# Game  546  : Winner is  p1
# TIE
# Game  547  : Winner is  TIE
# Winner is  p1
# Game  548  : Winner is  p1
# Winner is  p1
# Game  549  : Winner is  p1
# Winner is  p1
# Game  550  : Winner is  p1
# Winner is  p1
# Game  551  : Winner is  p1
# Winner is  p1
# Game  552  : Winner is  p1
# Winner is  p1
# Game  553  : Winner is  p1
# Winner is  p1
# Game  554  : Winner is  p1
# Winner is  p1
# Game  555  : Winner is  p1
# Winner is  p1
# Game  556  : Winner is  p1
# Winner is  p1
# Game  557  : Winner is  p1
# Winner is  p1
# Game  558  : Winner is  p1
# Winner is  p1
# Game  559  : Winner is  p1
# Winner is  p1
# Game  560  : Winner is  p1
# Winner is  p1
# Game  561  : Winner is  p1
# Winner is  p1
# Game  562  : Winner is  p1
# Winner is  p1
# Game  563  : Winner is  p1
# Winner is  p1
# Game  564  : Winner is  p1
# Winner is  p1
# Game  565  : Winner is  p1
# Winner is  p1
# Game  566  : Winner is  p1
# Winner is  p1
# Game  567  : Winner is  p1
# Winner is  p1
# Game  568  : Winner is  p1
# Winner is  p1
# Game  569  : Winner is  p1
# Winner is  p1
# Game  570  : Winner is  p1
# Winner is  p1
# Game  571  : Winner is  p1
# Winner is  p1
# Game  572  : Winner is  p1
# Winner is  p1
# Game  573  : Winner is  p1
# Winner is  p1
# Game  574  : Winner is  p1
# Winner is  p1
# Game  575  : Winner is  p1
# Winner is  p1
# Game  576  : Winner is  p1
# Winner is  p1
# Game  577  : Winner is  p1
# TIE
# Game  578  : Winner is  TIE
# Winner is  p1
# Game  579  : Winner is  p1
# Winner is  p1
# Game  580  : Winner is  p1
# TIE
# Game  581  : Winner is  TIE
# Winner is  p1
# Game  582  : Winner is  p1
# Winner is  p1
# Game  583  : Winner is  p1
# Winner is  p1
# Game  584  : Winner is  p1
# Winner is  p1
# Game  585  : Winner is  p1
# Winner is  p1
# Game  586  : Winner is  p1
# Winner is  p1
# Game  587  : Winner is  p1
# Winner is  p1
# Game  588  : Winner is  p1
# TIE
# Game  589  : Winner is  TIE
# Winner is  p1
# Game  590  : Winner is  p1
# TIE
# Game  591  : Winner is  TIE
# Winner is  p1
# Game  592  : Winner is  p1
# Winner is  p1
# Game  593  : Winner is  p1
# Winner is  p1
# Game  594  : Winner is  p1
# Winner is  p1
# Game  595  : Winner is  p1
# Winner is  p2
# Game  596  : Winner is  p2
# Winner is  p1
# Game  597  : Winner is  p1
# Winner is  p1
# Game  598  : Winner is  p1
# TIE
# Game  599  : Winner is  TIE
# Winner is  p1
# Game  600  : Winner is  p1
# Winner is  p1
# Game  601  : Winner is  p1
# Winner is  p1
# Game  602  : Winner is  p1
# Winner is  p1
# Game  603  : Winner is  p1
# Winner is  p1
# Game  604  : Winner is  p1
# Winner is  p1
# Game  605  : Winner is  p1
# Winner is  p1
# Game  606  : Winner is  p1
# Winner is  p1
# Game  607  : Winner is  p1
# Winner is  p1
# Game  608  : Winner is  p1
# Winner is  p1
# Game  609  : Winner is  p1
# Winner is  p1
# Game  610  : Winner is  p1
# Winner is  p1
# Game  611  : Winner is  p1
# Winner is  p1
# Game  612  : Winner is  p1
# Winner is  p1
# Game  613  : Winner is  p1
# Winner is  p1
# Game  614  : Winner is  p1
# Winner is  p1
# Game  615  : Winner is  p1
# Winner is  p1
# Game  616  : Winner is  p1
# Winner is  p1
# Game  617  : Winner is  p1
# Winner is  p1
# Game  618  : Winner is  p1
# Winner is  p1
# Game  619  : Winner is  p1
# Winner is  p1
# Game  620  : Winner is  p1
# Winner is  p1
# Game  621  : Winner is  p1
# Winner is  p1
# Game  622  : Winner is  p1
# Winner is  p1
# Game  623  : Winner is  p1
# Winner is  p1
# Game  624  : Winner is  p1
# Winner is  p1
# Game  625  : Winner is  p1
# Winner is  p1
# Game  626  : Winner is  p1
# Winner is  p1
# Game  627  : Winner is  p1
# Winner is  p1
# Game  628  : Winner is  p1
# TIE
# Game  629  : Winner is  TIE
# Winner is  p1
# Game  630  : Winner is  p1
# Winner is  p1
# Game  631  : Winner is  p1
# Winner is  p1
# Game  632  : Winner is  p1
# Winner is  p1
# Game  633  : Winner is  p1
# Winner is  p1
# Game  634  : Winner is  p1
# Winner is  p1
# Game  635  : Winner is  p1
# Winner is  p1
# Game  636  : Winner is  p1
# Winner is  p1
# Game  637  : Winner is  p1
# Winner is  p1
# Game  638  : Winner is  p1
# Winner is  p1
# Game  639  : Winner is  p1
# Winner is  p1
# Game  640  : Winner is  p1
# Winner is  p1
# Game  641  : Winner is  p1
# Winner is  p1
# Game  642  : Winner is  p1
# Winner is  p1
# Game  643  : Winner is  p1
# Winner is  p1
# Game  644  : Winner is  p1
# Winner is  p1
# Game  645  : Winner is  p1
# Winner is  p1
# Game  646  : Winner is  p1
# Winner is  p1
# Game  647  : Winner is  p1
# Winner is  p1
# Game  648  : Winner is  p1
# Winner is  p1
# Game  649  : Winner is  p1
# Winner is  p1
# Game  650  : Winner is  p1
# Winner is  p1
# Game  651  : Winner is  p1
# TIE
# Game  652  : Winner is  TIE
# Winner is  p1
# Game  653  : Winner is  p1
# Winner is  p1
# Game  654  : Winner is  p1
# Winner is  p1
# Game  655  : Winner is  p1
# Winner is  p1
# Game  656  : Winner is  p1
# Winner is  p1
# Game  657  : Winner is  p1
# Winner is  p1
# Game  658  : Winner is  p1
# Winner is  p1
# Game  659  : Winner is  p1
# Winner is  p1
# Game  660  : Winner is  p1
# Winner is  p1
# Game  661  : Winner is  p1
# TIE
# Game  662  : Winner is  TIE
# TIE
# Game  663  : Winner is  TIE
# Winner is  p1
# Game  664  : Winner is  p1
# Winner is  p1
# Game  665  : Winner is  p1
# Winner is  p1
# Game  666  : Winner is  p1
# TIE
# Game  667  : Winner is  TIE
# Winner is  p1
# Game  668  : Winner is  p1
# Winner is  p1
# Game  669  : Winner is  p1
# Winner is  p1
# Game  670  : Winner is  p1
# Winner is  p1
# Game  671  : Winner is  p1
# Winner is  p1
# Game  672  : Winner is  p1
# Winner is  p1
# Game  673  : Winner is  p1
# Winner is  p1
# Game  674  : Winner is  p1
# Winner is  p2
# Game  675  : Winner is  p2
# Winner is  p1
# Game  676  : Winner is  p1
# TIE
# Game  677  : Winner is  TIE
# Winner is  p1
# Game  678  : Winner is  p1
# Winner is  p1
# Game  679  : Winner is  p1
# TIE
# Game  680  : Winner is  TIE
# Winner is  p1
# Game  681  : Winner is  p1
# Winner is  p1
# Game  682  : Winner is  p1
# Winner is  p1
# Game  683  : Winner is  p1
# Winner is  p1
# Game  684  : Winner is  p1
# Winner is  p1
# Game  685  : Winner is  p1
# Winner is  p1
# Game  686  : Winner is  p1
# Winner is  p1
# Game  687  : Winner is  p1
# Winner is  p1
# Game  688  : Winner is  p1
# Winner is  p1
# Game  689  : Winner is  p1
# Winner is  p1
# Game  690  : Winner is  p1
# TIE
# Game  691  : Winner is  TIE
# Winner is  p2
# Game  692  : Winner is  p2
# Winner is  p1
# Game  693  : Winner is  p1
# Winner is  p1
# Game  694  : Winner is  p1
# Winner is  p1
# Game  695  : Winner is  p1
# Winner is  p1
# Game  696  : Winner is  p1
# Winner is  p1
# Game  697  : Winner is  p1
# Winner is  p1
# Game  698  : Winner is  p1
# Winner is  p1
# Game  699  : Winner is  p1
# Winner is  p1
# Game  700  : Winner is  p1
# Winner is  p1
# Game  701  : Winner is  p1
# Winner is  p1
# Game  702  : Winner is  p1
# Winner is  p1
# Game  703  : Winner is  p1
# Winner is  p1
# Game  704  : Winner is  p1
# Winner is  p1
# Game  705  : Winner is  p1
# Winner is  p1
# Game  706  : Winner is  p1
# Winner is  p1
# Game  707  : Winner is  p1
# Winner is  p1
# Game  708  : Winner is  p1
# Winner is  p1
# Game  709  : Winner is  p1
# Winner is  p1
# Game  710  : Winner is  p1
# Winner is  p1
# Game  711  : Winner is  p1
# Winner is  p1
# Game  712  : Winner is  p1
# Winner is  p1
# Game  713  : Winner is  p1
# Winner is  p1
# Game  714  : Winner is  p1
# TIE
# Game  715  : Winner is  TIE
# Winner is  p1
# Game  716  : Winner is  p1
# Winner is  p1
# Game  717  : Winner is  p1
# Winner is  p1
# Game  718  : Winner is  p1
# Winner is  p1
# Game  719  : Winner is  p1
# Winner is  p1
# Game  720  : Winner is  p1
# Winner is  p1
# Game  721  : Winner is  p1
# TIE
# Game  722  : Winner is  TIE
# Winner is  p1
# Game  723  : Winner is  p1
# Winner is  p1
# Game  724  : Winner is  p1
# Winner is  p1
# Game  725  : Winner is  p1
# Winner is  p1
# Game  726  : Winner is  p1
# Winner is  p1
# Game  727  : Winner is  p1
# Winner is  p1
# Game  728  : Winner is  p1
# Winner is  p1
# Game  729  : Winner is  p1
# Winner is  p1
# Game  730  : Winner is  p1
# Winner is  p1
# Game  731  : Winner is  p1
# Winner is  p1
# Game  732  : Winner is  p1
# Winner is  p1
# Game  733  : Winner is  p1
# Winner is  p1
# Game  734  : Winner is  p1
# Winner is  p1
# Game  735  : Winner is  p1
# Winner is  p1
# Game  736  : Winner is  p1
# Winner is  p1
# Game  737  : Winner is  p1
# Winner is  p1
# Game  738  : Winner is  p1
# Winner is  p1
# Game  739  : Winner is  p1
# Winner is  p1
# Game  740  : Winner is  p1
# Winner is  p1
# Game  741  : Winner is  p1
# Winner is  p1
# Game  742  : Winner is  p1
# TIE
# Game  743  : Winner is  TIE
# Winner is  p1
# Game  744  : Winner is  p1
# Winner is  p1
# Game  745  : Winner is  p1
# Winner is  p1
# Game  746  : Winner is  p1
# Winner is  p1
# Game  747  : Winner is  p1
# Winner is  p1
# Game  748  : Winner is  p1
# Winner is  p1
# Game  749  : Winner is  p1
# TIE
# Game  750  : Winner is  TIE
# Winner is  p1
# Game  751  : Winner is  p1
# Winner is  p1
# Game  752  : Winner is  p1
# Winner is  p1
# Game  753  : Winner is  p1
# Winner is  p1
# Game  754  : Winner is  p1
# Winner is  p1
# Game  755  : Winner is  p1
# Winner is  p1
# Game  756  : Winner is  p1
# Winner is  p1
# Game  757  : Winner is  p1
# Winner is  p1
# Game  758  : Winner is  p1
# Winner is  p2
# Game  759  : Winner is  p2
# Winner is  p1
# Game  760  : Winner is  p1
# Winner is  p1
# Game  761  : Winner is  p1
# Winner is  p1
# Game  762  : Winner is  p1
# Winner is  p1
# Game  763  : Winner is  p1
# Winner is  p1
# Game  764  : Winner is  p1
# Winner is  p1
# Game  765  : Winner is  p1
# Winner is  p1
# Game  766  : Winner is  p1
# Winner is  p1
# Game  767  : Winner is  p1
# Winner is  p1
# Game  768  : Winner is  p1
# Winner is  p1
# Game  769  : Winner is  p1
# Winner is  p1
# Game  770  : Winner is  p1
# Winner is  p1
# Game  771  : Winner is  p1
# Winner is  p1
# Game  772  : Winner is  p1
# Winner is  p1
# Game  773  : Winner is  p1
# Winner is  p1
# Game  774  : Winner is  p1
# Winner is  p1
# Game  775  : Winner is  p1
# Winner is  p1
# Game  776  : Winner is  p1
# Winner is  p1
# Game  777  : Winner is  p1
# Winner is  p1
# Game  778  : Winner is  p1
# Winner is  p1
# Game  779  : Winner is  p1
# Winner is  p1
# Game  780  : Winner is  p1
# TIE
# Game  781  : Winner is  TIE
# Winner is  p1
# Game  782  : Winner is  p1
# Winner is  p1
# Game  783  : Winner is  p1
# Winner is  p1
# Game  784  : Winner is  p1
# Winner is  p1
# Game  785  : Winner is  p1
# Winner is  p1
# Game  786  : Winner is  p1
# Winner is  p1
# Game  787  : Winner is  p1
# Winner is  p1
# Game  788  : Winner is  p1
# Winner is  p2
# Game  789  : Winner is  p2
# Winner is  p1
# Game  790  : Winner is  p1
# Winner is  p1
# Game  791  : Winner is  p1
# Winner is  p1
# Game  792  : Winner is  p1
# Winner is  p1
# Game  793  : Winner is  p1
# Winner is  p1
# Game  794  : Winner is  p1
# Winner is  p1
# Game  795  : Winner is  p1
# Winner is  p1
# Game  796  : Winner is  p1
# Winner is  p1
# Game  797  : Winner is  p1
# Winner is  p1
# Game  798  : Winner is  p1
# Winner is  p1
# Game  799  : Winner is  p1
# Winner is  p1
# Game  800  : Winner is  p1
# Winner is  p1
# Game  801  : Winner is  p1
# Winner is  p1
# Game  802  : Winner is  p1
# Winner is  p1
# Game  803  : Winner is  p1
# Winner is  p1
# Game  804  : Winner is  p1
# Winner is  p1
# Game  805  : Winner is  p1
# Winner is  p1
# Game  806  : Winner is  p1
# Winner is  p1
# Game  807  : Winner is  p1
# Winner is  p1
# Game  808  : Winner is  p1
# Winner is  p1
# Game  809  : Winner is  p1
# TIE
# Game  810  : Winner is  TIE
# Winner is  p1
# Game  811  : Winner is  p1
# Winner is  p1
# Game  812  : Winner is  p1
# TIE
# Game  813  : Winner is  TIE
# Winner is  p1
# Game  814  : Winner is  p1
# Winner is  p1
# Game  815  : Winner is  p1
# Winner is  p1
# Game  816  : Winner is  p1
# Winner is  p1
# Game  817  : Winner is  p1
# Winner is  p1
# Game  818  : Winner is  p1
# Winner is  p1
# Game  819  : Winner is  p1
# Winner is  p1
# Game  820  : Winner is  p1
# Winner is  p1
# Game  821  : Winner is  p1
# Winner is  p1
# Game  822  : Winner is  p1
# Winner is  p1
# Game  823  : Winner is  p1
# Winner is  p1
# Game  824  : Winner is  p1
# Winner is  p1
# Game  825  : Winner is  p1
# Winner is  p1
# Game  826  : Winner is  p1
# Winner is  p1
# Game  827  : Winner is  p1
# Winner is  p1
# Game  828  : Winner is  p1
# Winner is  p1
# Game  829  : Winner is  p1
# Winner is  p1
# Game  830  : Winner is  p1
# Winner is  p1
# Game  831  : Winner is  p1
# Winner is  p1
# Game  832  : Winner is  p1
# Winner is  p1
# Game  833  : Winner is  p1
# Winner is  p1
# Game  834  : Winner is  p1
# Winner is  p1
# Game  835  : Winner is  p1
# Winner is  p1
# Game  836  : Winner is  p1
# Winner is  p1
# Game  837  : Winner is  p1
# Winner is  p1
# Game  838  : Winner is  p1
# Winner is  p1
# Game  839  : Winner is  p1
# Winner is  p1
# Game  840  : Winner is  p1
# Winner is  p1
# Game  841  : Winner is  p1
# TIE
# Game  842  : Winner is  TIE
# Winner is  p1
# Game  843  : Winner is  p1
# Winner is  p1
# Game  844  : Winner is  p1
# Winner is  p1
# Game  845  : Winner is  p1
# Winner is  p1
# Game  846  : Winner is  p1
# Winner is  p1
# Game  847  : Winner is  p1
# Winner is  p1
# Game  848  : Winner is  p1
# Winner is  p1
# Game  849  : Winner is  p1
# TIE
# Game  850  : Winner is  TIE
# Winner is  p1
# Game  851  : Winner is  p1
# Winner is  p1
# Game  852  : Winner is  p1
# TIE
# Game  853  : Winner is  TIE
# Winner is  p1
# Game  854  : Winner is  p1
# Winner is  p1
# Game  855  : Winner is  p1
# Winner is  p1
# Game  856  : Winner is  p1
# Winner is  p1
# Game  857  : Winner is  p1
# Winner is  p1
# Game  858  : Winner is  p1
# Winner is  p1
# Game  859  : Winner is  p1
# Winner is  p1
# Game  860  : Winner is  p1
# Winner is  p1
# Game  861  : Winner is  p1
# Winner is  p1
# Game  862  : Winner is  p1
# Winner is  p1
# Game  863  : Winner is  p1
# Winner is  p1
# Game  864  : Winner is  p1
# Winner is  p1
# Game  865  : Winner is  p1
# Winner is  p1
# Game  866  : Winner is  p1
# Winner is  p1
# Game  867  : Winner is  p1
# Winner is  p1
# Game  868  : Winner is  p1
# Winner is  p1
# Game  869  : Winner is  p1
# Winner is  p1
# Game  870  : Winner is  p1
# TIE
# Game  871  : Winner is  TIE
# Winner is  p1
# Game  872  : Winner is  p1
# Winner is  p1
# Game  873  : Winner is  p1
# TIE
# Game  874  : Winner is  TIE
# Winner is  p1
# Game  875  : Winner is  p1
# Winner is  p1
# Game  876  : Winner is  p1
# TIE
# Game  877  : Winner is  TIE
# Winner is  p1
# Game  878  : Winner is  p1
# Winner is  p1
# Game  879  : Winner is  p1
# Winner is  p1
# Game  880  : Winner is  p1
# Winner is  p1
# Game  881  : Winner is  p1
# Winner is  p1
# Game  882  : Winner is  p1
# Winner is  p1
# Game  883  : Winner is  p1
# Winner is  p1
# Game  884  : Winner is  p1
# Winner is  p1
# Game  885  : Winner is  p1
# Winner is  p1
# Game  886  : Winner is  p1
# Winner is  p1
# Game  887  : Winner is  p1
# Winner is  p1
# Game  888  : Winner is  p1
# Winner is  p1
# Game  889  : Winner is  p1
# Winner is  p1
# Game  890  : Winner is  p1
# Winner is  p1
# Game  891  : Winner is  p1
# Winner is  p1
# Game  892  : Winner is  p1
# Winner is  p1
# Game  893  : Winner is  p1
# Winner is  p1
# Game  894  : Winner is  p1
# Winner is  p1
# Game  895  : Winner is  p1
# Winner is  p1
# Game  896  : Winner is  p1
# Winner is  p1
# Game  897  : Winner is  p1
# Winner is  p1
# Game  898  : Winner is  p1
# Winner is  p1
# Game  899  : Winner is  p1
# Winner is  p1
# Game  900  : Winner is  p1
# Winner is  p1
# Game  901  : Winner is  p1
# Winner is  p1
# Game  902  : Winner is  p1
# Winner is  p1
# Game  903  : Winner is  p1
# Winner is  p1
# Game  904  : Winner is  p1
# Winner is  p1
# Game  905  : Winner is  p1
# Winner is  p1
# Game  906  : Winner is  p1
# Winner is  p1
# Game  907  : Winner is  p1
# Winner is  p1
# Game  908  : Winner is  p1
# Winner is  p1
# Game  909  : Winner is  p1
# Winner is  p1
# Game  910  : Winner is  p1
# Winner is  p1
# Game  911  : Winner is  p1
# Winner is  p1
# Game  912  : Winner is  p1
# Winner is  p1
# Game  913  : Winner is  p1
# Winner is  p1
# Game  914  : Winner is  p1
# TIE
# Game  915  : Winner is  TIE
# Winner is  p1
# Game  916  : Winner is  p1
# Winner is  p1
# Game  917  : Winner is  p1
# Winner is  p1
# Game  918  : Winner is  p1
# Winner is  p1
# Game  919  : Winner is  p1
# Winner is  p1
# Game  920  : Winner is  p1
# Winner is  p1
# Game  921  : Winner is  p1
# Winner is  p1
# Game  922  : Winner is  p1
# Winner is  p1
# Game  923  : Winner is  p1
# TIE
# Game  924  : Winner is  TIE
# Winner is  p2
# Game  925  : Winner is  p2
# Winner is  p1
# Game  926  : Winner is  p1
# Winner is  p1
# Game  927  : Winner is  p1
# Winner is  p1
# Game  928  : Winner is  p1
# Winner is  p1
# Game  929  : Winner is  p1
# Winner is  p1
# Game  930  : Winner is  p1
# Winner is  p1
# Game  931  : Winner is  p1
# Winner is  p1
# Game  932  : Winner is  p1
# Winner is  p1
# Game  933  : Winner is  p1
# Winner is  p1
# Game  934  : Winner is  p1
# Winner is  p1
# Game  935  : Winner is  p1
# Winner is  p1
# Game  936  : Winner is  p1
# Winner is  p1
# Game  937  : Winner is  p1
# Winner is  p1
# Game  938  : Winner is  p1
# Winner is  p1
# Game  939  : Winner is  p1
# Winner is  p1
# Game  940  : Winner is  p1
# Winner is  p1
# Game  941  : Winner is  p1
# Winner is  p1
# Game  942  : Winner is  p1
# Winner is  p1
# Game  943  : Winner is  p1
# Winner is  p1
# Game  944  : Winner is  p1
# Winner is  p1
# Game  945  : Winner is  p1
# Winner is  p1
# Game  946  : Winner is  p1
# Winner is  p1
# Game  947  : Winner is  p1
# Winner is  p1
# Game  948  : Winner is  p1
# Winner is  p1
# Game  949  : Winner is  p1
# Winner is  p1
# Game  950  : Winner is  p1
# Winner is  p1
# Game  951  : Winner is  p1
# Winner is  p1
# Game  952  : Winner is  p1
# Winner is  p1
# Game  953  : Winner is  p1
# Winner is  p1
# Game  954  : Winner is  p1
# Winner is  p1
# Game  955  : Winner is  p1
# Winner is  p1
# Game  956  : Winner is  p1
# Winner is  p1
# Game  957  : Winner is  p1
# Winner is  p1
# Game  958  : Winner is  p1
# Winner is  p1
# Game  959  : Winner is  p1
# Winner is  p1
# Game  960  : Winner is  p1
# Winner is  p1
# Game  961  : Winner is  p1
# Winner is  p1
# Game  962  : Winner is  p1
# Winner is  p1
# Game  963  : Winner is  p1
# Winner is  p1
# Game  964  : Winner is  p1
# Winner is  p1
# Game  965  : Winner is  p1
# Winner is  p1
# Game  966  : Winner is  p1
# Winner is  p1
# Game  967  : Winner is  p1
# Winner is  p1
# Game  968  : Winner is  p1
# Winner is  p1
# Game  969  : Winner is  p1
# Winner is  p1
# Game  970  : Winner is  p1
# Winner is  p1
# Game  971  : Winner is  p1
# TIE
# Game  972  : Winner is  TIE
# Winner is  p1
# Game  973  : Winner is  p1
# Winner is  p1
# Game  974  : Winner is  p1
# Winner is  p1
# Game  975  : Winner is  p1
# Winner is  p1
# Game  976  : Winner is  p1
# Winner is  p1
# Game  977  : Winner is  p1
# Winner is  p1
# Game  978  : Winner is  p1
# Winner is  p1
# Game  979  : Winner is  p1
# Winner is  p1
# Game  980  : Winner is  p1
# Winner is  p1
# Game  981  : Winner is  p1
# Winner is  p1
# Game  982  : Winner is  p1
# Winner is  p1
# Game  983  : Winner is  p1
# Winner is  p1
# Game  984  : Winner is  p1
# Winner is  p1
# Game  985  : Winner is  p1
# Winner is  p1
# Game  986  : Winner is  p1
# Winner is  p1
# Game  987  : Winner is  p1
# Winner is  p1
# Game  988  : Winner is  p1
# Winner is  p1
# Game  989  : Winner is  p1
# Winner is  p1
# Game  990  : Winner is  p1
# Winner is  p1
# Game  991  : Winner is  p1
# Winner is  p1
# Game  992  : Winner is  p1
# Winner is  p1
# Game  993  : Winner is  p1
# Winner is  p1
# Game  994  : Winner is  p1
# Winner is  p1
# Game  995  : Winner is  p1
# Winner is  p1
# Game  996  : Winner is  p1
# Winner is  p1
# Game  997  : Winner is  p1
# Winner is  p1
# Game  998  : Winner is  p1
# Winner is  p1
# Game  999  : Winner is  p1
# Winner is  p1
# Game  1000  : Winner is  p1
# Of the  1000  games, our Q Learner  has winrate = 0.928  and loserate = 0.012 . It has tie rate of   0.06
